# %% [markdown]
# <P> <img src="https://i.ibb.co/gyNf19D/nhslogo.png" alt="nhslogo" border="0" width="100" align="right"><font size="6"><b> CS6131 Database Design</b> </font>

# %% [markdown]
# # Project Scripting Phase Report Submission
# > _by Prannaya Gupta (M23604)_

# %% [markdown]
# ### Submission Instructions

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# * You will need to submit the following files in your final project submission:
#     * Your Jupyter Notebook report. Name the report `ProjectScriptingReport<YourName>.ipynb`.
#     * All relevant image files to be displayed in this report (make sure you use relative file referencing and the image will display in another computer).
#     * Attached each file one by one and upload on Coursemology.
# * Please print a copy of the final report to OneNote Individual Notebook space > Project. Double check on the image resolution. If the resolution is poor, please copy and paste the ORIGINAL clear image into the OneNote page (paste at the side of the printed image).
#
# * Any submission that fails to comply to the above instructions will result in upto 5% penalty.
#
# * You may wish to refer to the following reference to help organize and "beautify" your final report here. <br>
# https://thecodingbot.com/markdown-in-jupyter-ipython-notebook-cheatsheet/
# </div>

# %% [markdown]
# ### Section A: Overview & Business Rules

# %% [markdown]
# ### Overview

# %% [markdown]
# <div class="alert alert-block alert-warning">
# You may copy and paste the overview submitted in previous phase. Edits, if any, should be highlighted.
# </div>

# %% [markdown]
# The Research, Innovation and Enterprise (RIE) Department of NUS High School is a core pillar for the continued development of students in our school. With the Advanced Research Project (ARP) being a major component of our diploma, the RIE department has the immense responsibility to administrate various projects from various students. This especially important given the fact that the school gives students autonomy to participate in multiple projects with mentors from various research institutions under different time periods. However, recent years have shown that there are certain cracks forming in the database system employed by the RIE, which is incredibly problematic in administrating continuation projects, receiving project details and more.
#
# I believe that our RIE department will benefit from a RDBMS system to manage projects so that they have consistency in Project Details, allowing easier methods to search and sift through projects done by specific students, submit and receive Project Reports, Posters and ISEF/SSEF Forms, and help people get to know more about research done by Seniors and Juniors alike.

# %% [markdown]
# ### Business Rules

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Include your updated business rules writeup here. Any changes from previous submission should be highlighted.
# You may consider using HTML editor for easy editing e.g. <a href="https://onlinehtmleditor.dev/">https://onlinehtmleditor.dev/</a>
# </div>

# %% [markdown]
# <!--<p><span style="font-size:16px"><span style="font-family:Arial,Helvetica,sans-serif">This&nbsp; is a test. <span style="background-color:#ffff00">The statement I have edited is this.</span></span></span></p>-->
#
# We design a basic database system to store the research projects of NUS High School students.
#
# A **person** is any individual with a *name* and a unique *email address*. This person <span style="background-color:#ffff00">must</span> be a **student**, a **teacher** or a **research mentor**, or any set of 2-3 such roles.
#
# > <span style="background-color:#ffff00">Rationale behind the above condition: There are certain students who graduated to become teachers in NUS High, for instance Ms Han Shutong who used to teach in NUS High. Owing to the fact that NUS High is aging, we could expect more students to come back to teach, and with that, we have students who were also initially teachers. While it would also make sense for them to create a new teacher account under their new school email, it is also true that their student account will be active for quite a while. Another reason is that many projects are mentored by mentors who are, in fact, students themselves. Examples include projects mentored by PhD Candidates or even NUS Students (which, while uncommon, has happened before and is in the scope of the dataset I am currently assembling).</span>
#
# The **student** must be either a **NUSH student** or an **external student**. A **NUSH student** has a *profile picture*, *NUSH student ID* (derived from the email), <span style="background-color:#ffff00">a <i>password</i></span> and *graduation year*. ~~An **external student** must have a *phone number*.~~
#
# The **teacher** must be either a **NUSH teacher** or an **external teacher**. A **NUSH teacher** has a *profile picture* <span style="background-color:#ffff00">and a <i>password</i></span>~~and *preferred email address* (NUSH/NUS)~~. A **NUSH teacher** can further be a **teacher mentor** or an **administrator**, or both, but they are not tied down to any of these roles. ~~An **external teacher** has a *phone number*.~~
#
# A **research mentor** is defined as a researcher <span style="background-color:#ffff00">working in some institution</span>.~~with a *phone number* and an optional *orcid*~~
#
# A **department** is defined to store information for the teachers and the projects. There are a total of 8 departments (MA, PH, BI, CM, CS, RE, EL and HU), and each department has a unique *name* and *department id* (the aforementioned codes are the *department id* values).
#
# A **project** is any research work performed over the course of a single *year* of submission. The project is assigned a unique *project code*, is presented in a *year* and also has a non-empty *project title*, *project abstract* and *project report PDF*.
#
# An **institution** is an educational or research location with a unique *name*, *initials* and <span style="background-color:#ffff00"><i>location</i></span>. This **institution** must either be an **external school**, a **research institution**, <span style="background-color:#ffff00">a <b>research organiser</b>, a <b>publisher</b></span> or any combination of the four.
#
# A **research event** is an event with a unique *event ID* <span style="background-color:#ffff00">and *year* pair</span>, *name*, *date range* composed of a *start date* and *end date*, *format*, ~~*organiser*, *website url* and *year* (derived from *start date*)~~. A **research event** can be a **competiton**, **conference**, both or neither. A **conference** has a *doi* <span style="background-color:#ffff00">(Digital Object Identifier to classify papers and conferences easily. See more at http://www.doi.org/)</span>. A **competiton** has multiple *award types*.
#
# An **accomplishment** is some milestone achieved by a submission, categorised by a unique *accomplishment ID*. An accomplishment <span style="background-color:#ffff00">must</span> either be an **award** or a **publication**. An **award** has a *name* and a *prize ~~money~~*. A **publication** has a unique *doi*. <span style="background-color:#ffff00">For more details regarding *doi*, see above. A <b>publication</b> must be further subdivided into either a <b>conference publication</b> or a <b>journal publication</b>. A <b>journal publication</b> has a separate <i>url</i> to the website.</span>
#
# A **submission** is a submission to a **research event**<span style="background-color:#ffff00">, uniquely defined based on a <b>research event</b> and a separate <i>code</i>, </span> with a ~~unique *submission ID*, *submision date*,~~ *submission title* and *submission abstract*~~and multiple *submission documents* (each of which is a PDF)~~.
#
# <span style="background-color:#ffff00">A <b>submission document</b> is a document uniquely defined by a <b>submission</b> and a separate <i>document filename</i>. The document also has a <i>document file</i>, and is also logged via a <i>lastUpdated</i> parameter, which is by default the time of update to the database.</span>
#
# <span style="background-color:#ffff00">A <b>journal</b> is an avenue for researchers to publish their work, and is uniquely defined by <i>issn</i> (International Standard Serial Number).</span>
#
# <span style="background-color:#00ffff">START OF RELATIONSHIPS</span>
#
# <span style="background-color:#ffff00">A <b>teacher</b> comes from ONE specific <b>department</b>. A <b>department</b> may have zero or more <b>teachers</b>. A <b>project</b> comes from ONE specific <b>department</b>. A <b>department</b> may have zero or more <b>projects</b>.</span>
#
# An **external school** has multiple **external teachers**, and each **external teacher** must come from one **external school**. An **external teacher** is the emergency contact of multiple **external students**, and each **external student** must have one **external teacher** as an emergency contact.
#
# A **research mentor** may work at multiple **research institutes** under a specific *department* with a specific *role* at a specific *office ~~location~~ address* at each **research institute**. A **research institute** may have multiple **research mentors**, each of whom hail from specific *departments* and specific *roles*.
#
# > <span style="background-color:#ffff00">_Addressing the necessity of storing the various research institutes_: There are specific people in the industry who work in differing research institutes and they indicate as such, hence it seems more reasonable to store their multiple institutes.</span>
#
# A **student** can work on zero or more **projects**~~, each constituting a *work range*, which is composed of a *start date* and an *end date*~~. A **project** also has one or more **students**.~~, who each work across a *work range* composed of a *start date* and an *end date*.~~
#
# A **teacher mentor** administrates one or more **projects**. A **project** has exactly one **teacher mentor**.
#
# A **research mentor** mentors one or more **projects**, each of which has an allocated *first meeting location* and *first meeting date and time*. A **project** is mentored by zero or more **research mentors**.
#
# A _**project**_ can be optionally continued onto a _new **project**_.
#
# A **student** can optionally submit one or more **submissions** to each **project**. A **student** can also optionally submit a **submission** for one or more **projects**. A **project** can be optionally submitted by one or more **students** for each **submission**. A **project** can have one ore more **submissions** for each **student** submitting. A **submission** must be submitted by one or more **students** for a **project**. A **submission** must submit one or more **projects** for each **student**.
#
# A **submission** can win zero or more **accomplishments**. An **accomplishment** can optionally be won through a **submission**.
#
# <span style="background-color:#ffff00">A <b>research event</b> is organised by one or more <b>research organisers</b>. A <b>research organiser</b> must organise one or more <b>research events</b>.</span>
#
# <span style="background-color:#ffff00">A <b>journal</b> is published by one or more <b>publishers</b>. A <b>publisher</b> can publish one or more <b>journals</b>. A <b>journal publication</b> is published in one <b>journal</b>. A <b>journal</b> publishes one or more <b>journal publication.</b>.</span>
#
# ~~A **competition** grants zero or more **awards**. An **award** must be granted by a **competition**. A **conference** publishes zero or more **publications**. An **publication** must be published by a **conference**.~~
#
#
# **Legend**:
#
# |Markup|Item|
# |---|---|
# |**bold**|Entity|
# |_italics_|Attribute|

# %% [markdown]
# ### Section B: ER Model

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Screen shot your previous ER (with teacher's marking) and insert image below (double click on the markdown and insert your img name).
# </div>

# %% [markdown]
# <img src="marked_er.png">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Attached the image of your UPDATED ER Model here. Highlight changes made.
# </div>

# %% [markdown]
# Minor Changes in both diagrams:
# - `accTitle` should be `accId`
# - Ignore the `date` parameter in `PUBLISHED_IN`
#
# High Res:
# <img src="new_er.png">
#
# Highlighted
# <img src="highlighted_new_er.png">

# %% [markdown]
# #### Major Changes
#
# ##### Making `year` a key in `ResearchEvent`
# This is to make a distinction between multiple iterations of the same event (eg SSEF 2021, SSEF 2022, SSEF 2023, ISYF 2021, ISYF 2022 etc).
#
# ##### Making `organiser` a relationship between a `Institution` and `ResearchEvent` rather than an attribute
# This is done to standardize information in this regard.
#
# ##### Usage of Weak Entities to denote `Submission`
# Submissions are largely described by not just the code it has, but also the event it is from. For instance, my SSEF submission code in 2021, BE018 is the same as Yuan Xi's SSEF submission code in 2023. Yet these projects are completely different. Hence, it is more reasonable to make a Submission be largely defined by a Research Event (eg SSEF 2021, SSEF 2023).
#
# ##### Changing `subDocs` multi-valued entity into a Weak Entity `Document`
# Each file needs information regarding filename (for download) and document, with last updated information useful for data management.
#
# ##### Introduction of `Department` Entity
# Used to standardize department information between NUSH Teachers and Projects.
#
# ##### Removal of `firstMeeting*` in `MENTORS`
# This information is rather redundant and has hence been removed.
#
# ##### Introduction of `Journal` and `JournalPublication`
# I realise that one might submit to a Journal too.

# %% [markdown]
# ### Section C: Relational Model

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Screen shot your previous Relational Model (with teacher's marking) and insert image below.
# </div>

# %% [markdown]
# <img src="marked_rel.png">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Attached the image of your UPDATED Relational Model here.  Highlight changes made.
# </div>

# %% [markdown]
# Minor Changes in both diagrams:
# - `accTitle` should be `accId`
#
# High Res:
# <img src="new_rel.png">
#
# Highlighted
# <img src="highlighted_new_rel.png">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Justify your mapping strategy from ER to relational, particularly if the approach deviates from the norm, or you have inheritance in your ER model (i.e. which strategy is adopted for inheritance mapping and why).
# </div>

# %% [markdown]
# For the inheritance of Person to subclasses, the method involving "Multiple relations-subclass relations only" is utilised due to the large variation in data, in addition to the fact that the intersection is limited between the 3 subclasses. Hence, this separation can still be entertained.
#
# For the inheritance of Student, we utilise the "Multiple relations-Superclass and subclasses" strategy as we require a parent subclass relational table to refer to both types of students.
#
# For Institution, we utilise the "Single relation with multiple type attributes" as there are not any significant attributes in each subclass. Hence, it is less of a waste of space to utilise this strategy.
#
# For Accomplishment, we note that a majority of the Accomplishments are Awards, hence it is more useful for us to utilise the "Single relation with one type attribute" for Award, but we use the "Multiple relations-Superclass and subclass" strategy to encode Publication to conserve memory space. For Publication, we use the "Single relation with one type attribute" as there is a higher number of Journal articles present in the dataset, and this allows us to save space via not having to repeat the `accTitle` id attribute.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# If the relational schema mapped from the ER is not in 3NF, propose relevant normalization to make all relations in 3NF. You may leave this part blank if no further normalization is required.
# </div>

# %% [markdown]
# No further normalization is required.

# %% [markdown]
# ### Section D: DDL Schema

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Fill in the relevant code required to create the relations for your database based on the relational model in Section C. <br>
# Your code should be end to end (i.e. I should be able to execute on my computer without much problem).
# Please ensure your code can be seen clearly on oneNote.
# </div>

# %%
# %load_ext sql

# %%
# %sql mysql+mysqldb://root:admin@localhost/

# %%
# %%sql
#
# DROP DATABASE IF EXISTS ARXIV;
# CREATE DATABASE ARXIV;
# USE ARXIV;
#
# CREATE TABLE Institution ( #done
#     instId VARCHAR(10) NOT NULL,
#     name VARCHAR(100) NOT NULL DEFAULT "",
#     address VARCHAR(150) NOT NULL DEFAULT "",
#     isSchool BOOLEAN NOT NULL DEFAULT 0,
#     isInstitute BOOLEAN NOT NULL DEFAULT 0,
#     isOrganiser BOOLEAN NOT NULL DEFAULT 0,
#     isPublisher BOOLEAN NOT NULL DEFAULT 0,
#     primary key (instId)
# );
#
# CREATE TABLE Department ( #done
#     deptId CHAR(2) NOT NULL,
#     name VARCHAR(50) NOT NULL DEFAULT "",
#     primary key (deptId)
# );
#
# CREATE TABLE NUSHTeacher ( #done
#     email VARCHAR(255) NOT NULL,
#     name VARCHAR(100) NOT NULL DEFAULT "",
#     pfp BLOB,
#     isAdmin BOOLEAN NOT NULL DEFAULT 0,
#     isMentor BOOLEAN NOT NULL DEFAULT 0,
#     deptId CHAR(2),
#     primary key (email),
#     foreign key (deptId) references Department(deptId) on delete set null on update cascade
# );
#
# CREATE TABLE ExternalTeacher ( #done
#     email VARCHAR(255) NOT NULL,
#     name VARCHAR(100),
#     schId VARCHAR(10),
#     primary key (email),
#     foreign key (schId) references Institution(instId) on delete set null on update cascade
# );
#
#
# CREATE TABLE Student ( #done
#     email VARCHAR(255) NOT NULL, # see https://stackoverflow.com/questions/386294/what-is-the-maximum-length-of-a-valid-email-address
#     name VARCHAR(100),
#     primary key (email)
# );
#
# CREATE TABLE NUSHStudent ( #done
#     email VARCHAR(255) NOT NULL,
#     pwd VARCHAR(20),
#     pfp BLOB,
#     gradYear INT(4),
#     nush_sid VARCHAR(8),
#     primary key (email),
#     foreign key (email) references Student(email) on delete cascade on update cascade
# );
#
# CREATE TABLE ExternalStudent ( #done
#     email VARCHAR(255) NOT NULL,
#     emergencyEmail VARCHAR(255),
#     primary key (email),
#     foreign key (email) references Student(email) on delete cascade on update cascade,
#     foreign key (emergencyEmail) references ExternalTeacher(email) on delete set null on update cascade
# );
#
# CREATE TABLE ResearchMentor ( #done
#     email VARCHAR(255) NOT NULL,
#     name VARCHAR(100),
#     primary key (email)
# );
#
# CREATE TABLE Works_At ( #done
#     mentorEmail VARCHAR(255),
#     instId VARCHAR(10),
#     dept VARCHAR(100),
#     role VARCHAR(100),
#     officeAddr VARCHAR(100),
#     primary key (mentorEmail, instId),
#     foreign key (mentorEmail) references ResearchMentor(email) on delete cascade on update cascade,
#     foreign key (instId) references Institution(instId) on delete cascade on update cascade
# );
#
# CREATE TABLE Project ( #done
#     pcode VARCHAR(20) NOT NULL,
#     title VARCHAR(200) NOT NULL,
#     abstract VARCHAR(2000),
#     reportPdf BLOB,
#     year INT(4),
#     deptId CHAR(2),
#     teacherEmail VARCHAR(255),
#     primary key (pcode),
#     foreign key (deptId) references Department(deptId) on delete set null on update cascade,
#     foreign key (teacherEmail) references NUSHTeacher(email) on delete set null on update cascade
# );
#
# CREATE TABLE ProjectContinuation ( #done
#     prevPcode VARCHAR(20) NOT NULL,
#     nextPcode VARCHAR(20) NOT NULL,
#     foreign key (prevPcode) references Project(pcode) on delete cascade on update cascade,
#     foreign key (nextPcode) references Project(pcode) on delete cascade on update cascade
# );
#
# CREATE TABLE Mentors ( #done
#     mentorEmail VARCHAR(255) NOT NULL,
#     pcode VARCHAR(20) NOT NULL,
#     foreign key (pcode) references Project(pcode) on delete cascade on update cascade,
#     foreign key (mentorEmail) references ResearchMentor(email) on delete cascade on update cascade
# );
#
# CREATE TABLE Works_On ( #done
#     studentEmail VARCHAR(255) NOT NULL,
#     pcode VARCHAR(20) NOT NULL,
#     primary key(studentEmail, pcode),
#     foreign key (pcode) references Project(pcode) on delete cascade on update cascade,
#     foreign key (studentEmail) references Student(email) on delete cascade on update cascade
# );
#
# CREATE TABLE ResearchEvent ( #done
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     name VARCHAR(100) NOT NULL,
#     start_date TIMESTAMP NOT NULL,
#     end_date TIMESTAMP NOT NULL,
#     format VARCHAR(10),
#     isCompetition BOOLEAN NOT NULL DEFAULT 0,
#     isConference BOOLEAN NOT NULL DEFAULT 0,
#     confDoi VARCHAR(200),
#     primary key (eventId, year)
# );
#
# CREATE TABLE AwardTypes ( #done
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     awardType VARCHAR(100) NOT NULL,
#     primary key (eventId, year, awardType),
#     foreign key (eventId, year) references ResearchEvent(eventId, year) on delete cascade on update cascade
# );
#
# CREATE TABLE Organises ( #done
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     instId VARCHAR(10) NOT NULL,
#     primary key (eventId, year, instId),
#     foreign key (eventId, year) references ResearchEvent(eventId, year) on delete cascade on update cascade,
#     foreign key (instId) references Institution(instId) on delete cascade on update cascade
# );
#
# CREATE TABLE Submission ( #done
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     code VARCHAR(20) NOT NULL,
#     subTitle VARCHAR(200) NOT NULL,
#     subAbstract VARCHAR(2000) NOT NULL,
#     primary key(eventId, year, code),
#     foreign key(eventId, year) references ResearchEvent(eventId, year) on delete cascade on update cascade
# );
#
# CREATE TABLE Document (
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     code VARCHAR(20) NOT NULL,
#     filename VARCHAR(20) NOT NULL,
#     doc BLOB NOT NULL,
#     lastUpdated TIMESTAMP NOT NULL default CURRENT_TIMESTAMP,
#     primary key(eventId, year, code, filename),
#     foreign key(eventId, year, code) references Submission(eventId, year, code) on delete cascade on update cascade
# );
#
# CREATE TABLE Submits ( #done
#     studentEmail VARCHAR(255) NOT NULL,
#     pcode VARCHAR(20) NOT NULL,
#     eventId VARCHAR(15) NOT NULL,
#     year INT(4) NOT NULL,
#     code VARCHAR(20) NOT NULL,
#     primary key(studentEmail, pcode, eventId, year, code),
#     foreign key(studentEmail) references Student(email) on delete cascade on update cascade,
#     foreign key(pcode) references Project(pcode) on delete cascade on update cascade,
#     foreign key(eventId, year, code) references Submission(eventId, year, code) on delete cascade on update cascade
# );
#
# CREATE TABLE Accomplishment (
#     accId INT NOT NULL AUTO_INCREMENT,
#     #accTitle VARCHAR(200) NOT NULL,
#     isAward BOOLEAN NOT NULL DEFAULT 0,
#     name VARCHAR(100),
#     prize VARCHAR(100),
#     eventId VARCHAR(15),
#     year INT(4),
#     code VARCHAR(20),
#     primary key(accId),
#     foreign key(eventId, year, code) references Submission(eventId, year, code) on delete set null on update cascade
# );
#
# CREATE TABLE Journal ( #done
#     issn INT(8) NOT NULL,
#     name VARCHAR(100) NOT NULL,
#     primary key(issn)
# );
#
# CREATE TABLE PublishedBy ( #done
#     issn INT(8) NOT NULL,
#     instId VARCHAR(10) NOT NULL,
#     primary key(issn, instId),
#     foreign key(issn) references Journal(issn) on delete cascade on update cascade,
#     foreign key(instId) references Institution(instId) on delete cascade on update cascade
# );
#
# CREATE TABLE Publication (
#     accId INT NOT NULL,
#     pubTitle VARCHAR(200) NOT NULL,
#     doi VARCHAR(200),
#     isJournal BOOLEAN NOT NULL DEFAULT 0,
#     url VARCHAR(300),
#     journISSN INT(8),
#     primary key(accId),
#     foreign key(accId) references Accomplishment(accId) on delete cascade on update cascade,
#     foreign key(journISSN) references Journal(issn) on delete cascade on update cascade
# );
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 23 rows affected.
# 1 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Section E: Data Population Script

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Fill in relevant code to populate data into your database. Note that you should use INSERT commands.
# You should populate each table with at least 5 to 10 records (as a prototype). You may continue adding more data over term break to prepare for the final project. This current submitted data set need not be final/complete, but should be sufficient to demonstrate the results in Section F.
#
# Note that data should be realistic and logically related / coherent.
# </div>

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\prann\anaconda3\envs\analytics\lib\site-packages (8.0.32)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in c:\users\prann\anaconda3\envs\analytics\lib\site-packages (from mysql-connector-python) (3.20.3)

# %%
import mysql.connector

db = mysql.connector.connect(
    host="localhost",
    user="root",
    password="admin",
    database="arxiv"
)

cur = db.cursor()

cur.execute("SHOW TABLES")

for x in cur:
    print(x)
# Out:
# ('accomplishment',)
# ('awardtypes',)
# ('department',)
# ('document',)
# ('externalstudent',)
# ('externalteacher',)
# ('institution',)
# ('journal',)
# ('mentors',)
# ('nushstudent',)
# ('nushteacher',)
# ('organises',)
# ('project',)
# ('projectcontinuation',)
# ('publication',)
# ('publishedby',)
# ('researchevent',)
# ('researchmentor',)
# ('student',)
# ('submission',)
# ('submits',)
# ('works_at',)
# ('works_on',)

# %%
sql = "INSERT INTO Institution VALUES (%s, %s, %s, %s, %s, %s, %s)"
schools = [
    ("RI", "Raffles Institution", "1 Raffles Institution Ln, Singapore 575954", True, True, False, False),
    ("HCI", "Hwa Chong Institution", "661 Bukit Timah Road, Singapore 269734", True, False, True, False),
    ('YIJC', 'Yishun Innova Junior College', "3 Yishun Ring Rd, Singapore 768675", True, False, False, False),
    ('EJC', 'Eunoia Junior College', "2 Sin Ming Pl, Singapore 573838", True, False, False, False),
    ('RGS', "Raffles Girls' School", "2 Braddell Rise, Singapore 318871", True, False, False, False),
    ('ACSI', 'Anglo-Chinese School (Independent)', "121 Dover Rd, Singapore 139650", True, False, False, False),
    ('MGS', "Methodist Girls' School", "11 Blackmore Dr, Singapore 599986", True, False, False, False),
    ('NYGH', "Nanyang Girls' High School", "2 Linden Dr, Singapore 288683", True, False, False, False),
    ('ASRJC', 'Anderson Serangoon Junior College', "4500 Ang Mo Kio Ave 6, Singapore 569843", True, False, True, False),
    ('NJC', 'National Junior College', "37 Hillcrest Rd, Singapore 288913", True, False, False, False),
    ('ACJC', 'Anglo-Chinese Junior College', "25 Dover Cl E, Singapore 139745", True, False, False, False),
    ('SAJC', "Saint Anthony's Junior College", "5 Sorby Adams Dr, Singapore 357691", True, False, False, False),
    ('VJC', 'Victoria Junior College', "20 Marine Vista, Singapore 449035", True, False, False, False),
    ('VS', 'Victoria School', "2 Siglap Link, Singapore 448880", True, False, False, False),
    ('CGSS', "Cedar Girls' School", "1 Cedar Ave, Singapore 349692", True, False, False, False),
    ('SJI', "Saint Joseph's Institution", "38 Malcolm Rd, Singapore 308274", True, False, False, False),
    ("TJC", "Temasek Junior College", "22 Bedok S Rd, Singapore 469278", True, False, False, False),
    ("DHS", "Dunman High School", "10 Tg Rhu Rd, Singapore 436895", True, False, False, False)
]

institutes = [
    ("SP", "Singapore Polytechnic", "500 Dover Rd, Singapore 139651", True, True, False, False),
    ('SCS', 'Science Centre Singapore', "15 Science Centre Rd, Singapore 609081", False, True, True, False),
    ('NUS', 'National University of Singapore', "21 Lower Kent Ridge Rd, Singapore 119077", False, True, False, True),
    ('NTU', 'Nanyang Technological University', "50 Nanyang Ave, 639798", False, True, False, False),
    ('SUTD', 'Singapore University of Technology and Design', "8 Somapah Rd, Singapore 487372", False, True, False, False),
    ('SMU', 'Singapore Management University', "81 Victoria St, Singapore 188065", False, True, False, False),
    ('SIT', 'Singapore Institute of Technology', "10 Dover Dr, Singapore 138683", False, True, False, False),
    ('DIGI', 'Digipen Institute of Technology', "510 Dover Rd, #03-01 SIT@SP, Building 139660", False, True, False, False),
    ('NIE', 'National Institute of Education', "1 Nanyang Walk, Singapore 637616", False, True, False, False),
    ('NUH', 'National University Hospital', "5 Lower Kent Ridge Rd, Singapore 119074", False, True, False, False),
    ('SGH', 'Singapore General Hospital', "31 Third Hospital Ave, Singapore 168753", False, True, False, False),
    ('ASTAR', 'Agency of Science, Technology and Research', "1 Fusionopolis Way, #20-10 Connexis, Singapore 138632", False, True, True, False),
    ('DSTA', 'Defence Science and Technology Agency', "1 Depot Rd, Singapore 109679", False, True, False, False),
    ('DSO', 'Defence Science Organisation', "12 Science Park Drive, Singapore 118225", False, True, False, False),
    ('NERI', 'NUS Environmental Research Institute', "5A Engineering Drive 1, #02-03 T-Lab Building, Singapore 117411", False, True, False, False),
    ('YLL', 'Yong Loo Lin School of Medicine', "10 Medical Dr, Singapore 117597", False, True, False, False),
    ('IMRE', 'Institute of Materials Research and Engineering', "2 Fusionopolis Way, Singapore 138634", False, True, False, False),
    ('TLL', 'Temasek Life Sciences Laboratory', "1 Research Link National University of Singapore Singapore 117604", False, True, False, False),
    ('SERI', 'Singapore Eye Research Institute', "The Academia, 20 College Rd, Level 6 Discovery Tower, Singapore 169856", False, True, False, False),
    ('BII', 'Bioinformatics Institute', "30 Biopolis St, Matrix, Singapore 138671", False, True, False, False),
    ('NSPC', 'NuSpace', "Blk 71 Ayer Rajah Crescent, #05-21, Singapore 139951", False, True, False, False),
    ('IMCB', 'Institute of Molecular and Cell Biology', "61 Biopolis Dr, Proteos, Singapore 138673", False, True, False, False),
    ('SRIS', 'Skin Research Institute of Singapore', "11 Mandalay Rd, #17-01, Singapore 308232", False, True, False, False),
    ('IHPC', 'Institute of High Performance Computing', "1 Fusionopolis Way, #16-16 Connexis, Singapore 138632", False, True, False, False),
    ("IIR", "Institute for Infocomm Research", "1 Fusionopolis Way, #21-01 Connexis, Singapore 138632", False, True, False, False)
]

organisers = [
    ("HKFYG", "Hong Kong Federation of Youth Groups", "The Hong Kong Federation Of Youth Groups Building, 21 Pak Fuk Rd, Tsat Tsz Mui, Hong Kong", False, False, True, False),
    ("IRC", "International Researchers Club", "511 Upper Jurong Rd, Singapore 638366", False, False, True, False),
    ("IPS", "Institute of Physics Singapore", "2 Science Drive 3, Singapore 117542", False, False, False, True),
    ("ASHK", "The Academy of Sciences of Hong Kong", "10 Science Park W Ave, Science Park, Hong Kong", False, False, True, False),
    ("IEEE", "Institute of Electrical and Electronics Engineers", "445 and 501 Hoes Lane, Piscataway, NJ 08854-4141 USA", False, False, True, True),
    ("AAS", "American Astronomical Society", "1667 K Street NW, Suite 800, Washington, DC 20006 USA", False, False, False, True),
    ("IOP", "IOP Publishing", "", False, False, False, True),
    ("EPS", "European Physical Society", "", False, False, False, True),
    ("WS", "World Scientific Publishing", "5 Toh Tuck Link, Singapore 596224", False, False, False, True),
    ("ACES", "Asian Chemical Editorial Society", "", False, False, False, True),
    ("WVCH", "Wiley-VCH", "Boschstraße 12, 69469 Weinheim", False, False, False, True)
]

cur.executemany(sql, schools)
cur.executemany(sql, institutes)
cur.executemany(sql, organisers)

db.commit()

print(cur.rowcount, "was inserted.")
# Out:
# 11 was inserted.

# %%
sql = "INSERT INTO Department VALUES (%s, %s)"

departments = [
    ('BI', 'Biology'), 
    ('CM', 'Chemistry'), 
    ('CS', 'Computer Science'), 
    ('EL', 'English Language & Literature'), 
    ('HU', 'Humanities'), 
    ('MA', 'Mathematics & Statistics'), 
    ('PH', 'Physics & Engineering'), 
    ('RE', 'Research, Innovation and Enterprise')
]

cur.executemany(sql, departments)

db.commit()

print(cur.rowcount, "was inserted.")
# Out:
# 8 was inserted.

# %%
import pandas as pd
sql = "INSERT INTO NUSHTeacher(email, name, deptId, isAdmin, isMentor) VALUES (%s, %s, %s, %s, %s)"
teachers = pd.read_csv("teachers.csv", encoding='windows-1252').values.tolist()
cur.executemany(sql, teachers)

db.commit()

print(cur.rowcount, "was inserted.")
# Out:
# 99 was inserted.

# %%
sql = "INSERT INTO ExternalTeacher VALUES (%s, %s, %s)"

exteachers = [
    ('fong_shi_ning@moe.edu.sg', 'Ms Fong Shi Ning', "TJC"), 
    ('goh.terence@dhs.edu.sg', 'Mr Terence Goh', 'DHS'),
    ("LIM_Cheng_Xiang@schools.gov.sg", "Lim Cheng Xiang", "YIJC")
]

cur.executemany(sql, exteachers)

db.commit()

print(cur.rowcount, "was inserted.")
# Out:
# 3 was inserted.

# %%
sql = "INSERT INTO Student(email, name) VALUES (%s, %s)"
students = pd.read_csv("students.csv").values.tolist()
cur.executemany(sql, students)

db.commit()

print(cur.rowcount, "rows were inserted.") # for interest of not making this notebook crash, I will not show the names.
# Out:
# 540 rows were inserted.

# %%
sql = "INSERT INTO NUSHStudent(email, pwd, gradYear, nush_sid) VALUES (%s, %s, %s, %s)"
nush_students = pd.read_csv("nush_students.csv").values.tolist()
cur.executemany(sql, nush_students)

db.commit()

print(cur.rowcount, "rows were inserted.") # for interest of not making this notebook crash, I will not show the names.
# Out:
# 536 rows were inserted.

# %%
sql = "INSERT INTO ExternalStudent VALUES (%s, %s)"

exteachers = [
    ('yau_le_qi@temasekjc.moe.edu.sg', 'fong_shi_ning@moe.edu.sg'), 
    ('ishneet_singh@temasekjc.moe.edu.sg', 'fong_shi_ning@moe.edu.sg'), 
    ("lam.yikting@dhs.edu.sg", 'goh.terence@dhs.edu.sg'),
    ("ashwin_lokesh@students.edu.sg", "LIM_Cheng_Xiang@schools.gov.sg")
]

cur.executemany(sql, exteachers)

db.commit()

# %%
sql = "INSERT INTO ResearchMentor VALUES (%s, %s)"

mentors = [
    ('arthurtay@nus.edu.sg', 'Arthur Tay'), 
    ('immanuel_koh@sutd.edu.sg', 'Immanuel Koh'), 
    ("truonghuu.tram@singaporetech.edu.sg", 'Tram Truong-Huu'),
    ("huangshaoying@sutd.edu.sg", "Huang Shaoying"),
    ("elie.hosry@singaporetech.edu.sg", "Elie Hosry"),
    ("zning@nuspace.sg", "Ng Zhen Ning"),
    ("rishabh_bhardwaj@mymail.sutd.edu.sg", "Rishabh Bhardwaj"),
    ("hklim@smu.edu.sg", "Lim How Khang"),
    ("hoinok.tsao@nie.edu.sg", "Tsao Hoi Nok")
]

cur.executemany(sql, mentors)

db.commit()

# %%
sql = "INSERT INTO Works_At VALUES (%s, %s, %s, %s, %s)"

works_at = [
    ('arthurtay@nus.edu.sg', 'NUS', "Electrical and Computer Engineering", "Adjunct Professor", "E4-08-12, 4 Engineering Drive 3, Singapore 117583"), 
    ('immanuel_koh@sutd.edu.sg', 'SUTD', "Architecture & Sustainable Design (ASD) and Design & Artificial Intelligence (DAI)", "Assistant Professor", None), 
    ("truonghuu.tram@singaporetech.edu.sg", 'SIT', None, "Assistant Professor", None),
    ("truonghuu.tram@singaporetech.edu.sg", "IIR", None, "Computer Scientist", None),
    ("huangshaoying@sutd.edu.sg", "SUTD", "Engineering Product Development", "Assistant Professor", None),
    ("elie.hosry@singaporetech.edu.sg", "DIGI", "Computer Science", "Principal Lecturer", None),
    ("hklim@smu.edu.sg", "SMU", "Centre for Computational Law", "Director", None),
    ("hoinok.tsao@nie.edu.sg", "NIE", "Natural Sciences & Science Education", "Assistant Professor", None),
    ("rishabh_bhardwaj@mymail.sutd.edu.sg", "SUTD", None, "PhD Candidate", None)
]

cur.executemany(sql, works_at)

db.commit()

# %%
sql = "INSERT INTO Project(pcode, title, abstract, year, deptId, teacherEmail) VALUES (%s, %s, %s, %s, %s, %s)"

projects = pd.read_csv("projects.csv").fillna("").values.tolist()

cur.executemany(sql, projects)
db.commit()

# %%
sql = "INSERT INTO Works_On(pcode, studentEmail) VALUES (%s, %s)"

works_on = pd.read_csv("works_on.csv").values.tolist()

cur.executemany(sql, works_on)
db.commit()

# %%
sql = "INSERT INTO ProjectContinuation VALUES (%s, %s)"

projects = [
    ("22.011.NUSH.PH", "23.030.NUSH.PH"),
    ("20.022.NUSE.PH", "23.018.NUSH.CS")
]

cur.executemany(sql, projects)
db.commit()

# %%
sql = "INSERT INTO Mentors VALUES (%s, %s)"

mentors = [
    ("zning@nuspace.sg", "21.048.NSPC.PH"),
    ("zning@nuspace.sg", "21.050.NSPC.PH"),
    ("zning@nuspace.sg", "23.013.NUSH.PH"),
    ("zning@nuspace.sg", "23.006.NSPC.PH"),
    ("rishabh_bhardwaj@mymail.sutd.edu.sg", "22.079.SUTD.CS"),
    ("truonghuu.tram@singaporetech.edu.sg", "23.010.SIT_.CS"),
    ("immanuel_koh@sutd.edu.sg", "21.029.SUTD.CS"),
    ("arthurtay@nus.edu.sg", "20.022.NUSE.PH"),
    ("huangshaoying@sutd.edu.sg", "22.077.SUTD.PH"),
    ("elie.hosry@singaporetech.edu.sg", "22.137.DIGI.CS"),
    ("hklim@smu.edu.sg", "22.041.SMU_.MA"),
    ("hoinok.tsao@nie.edu.sg", "22.066.NIE_.PH")
]

cur.executemany(sql, mentors)
db.commit()

# %%
sql = "INSERT INTO ResearchEvent VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"

events = [
    ['isyfDigital', 2021, 'International Science Youth Forum', '2021-01-19', '2021-01-22', 'Virtual', True, False, None],
    ['SSEF', 2021, 'Singapore Science and Engineering Fair', '2021-03-31', '2021-03-31', 'Virtual', True, False, None],
    ['GYSTB', 2021, 'Global Youth Science & Technology Bowl', '2021-06-19', '2021-06-20', 'Virtual', True, False, None],
    ['IRC-SET', 2021, 'International Researchers Club Conference on Science, Engineering and Technology', '2021-08-07', '2021-08-07', 'Virtual', True, True, ""],
    ['isyfDigital', 2022, 'International Science Youth Forum', '2022-01-18', '2022-01-21', 'Virtual', True, False, None],
    ['SSEF', 2022, 'Singapore Science and Engineering Fair', '2022-03-30', '2022-03-30', 'Virtual', True, False, None],
    ['STYau', 2022, 'S.T. Yau High School Science Award (Asia)', '2022-11-16', '2022-11-16', 'Virtual', True, False, None],
    ['SSEF', 2023, 'Singapore Science and Engineering Fair', '2023-03-08', '2023-03-09', 'IRL', True, False, None],
    ['Globecom', 2023, "IEEE Global Communications Conference", '2023-12-04', '2023-12-08', 'IRL', False, True, ""]
]

cur.executemany(sql, events)
db.commit()

# %%
sql = "INSERT INTO Organises VALUES (%s, %s, %s)"

organises = [
    ['isyfDigital', 2021, 'HCI'], ['SSEF', 2021, 'SCS'], ['SSEF', 2021, 'ASTAR'], 
    ['GYSTB', 2021, 'HKFYG'], ['IRC-SET', 2021, 'IRC'], ['isyfDigital', 2022, 'HCI'], 
    ['SSEF', 2022, 'SCS'], ['SSEF', 2022, 'ASTAR'], ['STYau', 2022, 'ASHK'], 
    ['SSEF', 2023, 'SCS'], ['SSEF', 2023, 'ASTAR'], ["Globecom", 2023, "IEEE"]
]

cur.executemany(sql, organises)
db.commit()

# %%
sql = "INSERT INTO AwardTypes VALUES (%s, %s, %s)"

awards = [
    ['isyfDigital', 2021, '1st Place'],
    ['isyfDigital', 2021, '2nd Place'],
    ['isyfDigital', 2021, '3rd Place'],
    ['SSEF', 2021, 'Gold'],
    ['SSEF', 2021, 'Silver'],
    ['SSEF', 2021, 'Bronze'],
    ['SSEF', 2021, 'Merit'],
    ['SSEF', 2021, 'SAAS Poster Award'],
    ['SSEF', 2021, 'ECS Special Award'],
    ['SSEF', 2021, 'IChemE Award'],
    ['SSEF', 2021, 'SMS Award for Ingenuity'],
    ['SSEF', 2021, 'SSMB Award'],
    ['SSEF', 2021, 'SUTD R&I Award: Artificial Intelligence'],
    ['SSEF', 2021, 'SUTD R&I Award: Aviation'],
    ['SSEF', 2021, 'SUTD R&I Award: Cities'],
    ['SSEF', 2021, 'SUTD R&I Award: Healthcare'],
    ['SSEF', 2021, 'SUTD R&I Award: Multi-Disciplinary'],
    ['SSEF', 2021, 'Yale-NUS Special Award'],
    ['GYSTB', 2021, 'Fourth Prize'],
    ['GYSTB', 2021, 'Third Prize'],
    ['GYSTB', 2021, 'Second Prize'],
    ['GYSTB', 2021, 'First Prize'],
    ['GYSTB', 2021, 'Gold Award'],
    ['GYSTB', 2021, 'Silver Award'],
    ['GYSTB', 2021, 'Bronze Award'],
    ['IRC-SET', 2021, 'Best Presenter Award'],
    ['IRC-SET', 2021, 'Best Paper Award'],
    ['SSEF', 2022, 'Gold'],
    ['SSEF', 2022, 'Silver'],
    ['SSEF', 2022, 'Bronze'],
    ['SSEF', 2022, 'Merit'],
    ['SSEF', 2022, 'SAAS Poster Award'],
    ['SSEF', 2022, 'ECS Special Award'],
    ['SSEF', 2022, 'IChemE Award'],
    ['SSEF', 2022, 'SMS Award for Ingenuity'],
    ['SSEF', 2022, 'SSMB Award'],
    ['SSEF', 2022, 'SUTD R&I Award: Artificial Intelligence'],
    ['SSEF', 2022, 'SUTD R&I Award: Aviation'],
    ['SSEF', 2022, 'SUTD R&I Award: Cities'],
    ['SSEF', 2022, 'SUTD R&I Award: Healthcare'],
    ['SSEF', 2022, 'SUTD R&I Award: Multi-Disciplinary'],
    ['SSEF', 2022, 'Yale-NUS Special Award'],
    ['STYau', 2022, 'Harry Shum High School Computer Science Gold Award'],
    ['STYau', 2022, 'Yuet-Wai Kan High School Biology Gold Award'],
    ['STYau', 2022, 'Ching W. Tang High School Chemistry Gold Award'],
    ['STYau', 2022, 'Charles K. Kao High School Physics Gold Award'],
    ['STYau',
     2022,
     'Chin-Yin Chiu High School Economic and Financial Modeling Gold Award'],
    ['STYau', 2022, 'Shiing-Shen Chern High School Mathematics Gold Award'],
    ['STYau', 2022, 'Silver Prize'],
    ['STYau', 2022, 'Honorable Mention'],
    ['SSEF', 2023, 'Gold'],
    ['SSEF', 2023, 'Silver'],
    ['SSEF', 2023, 'Bronze'],
    ['SSEF', 2023, 'Merit'],
    ['SSEF', 2023, 'SAAS Poster Award'],
    ['SSEF', 2023, 'ECS Special Award'],
    ['SSEF', 2023, 'IChemE Award'],
    ['SSEF', 2023, 'SMS Award for Ingenuity'],
    ['SSEF', 2023, 'SSMB Award'],
    ['SSEF', 2023, 'SUTD R&I Award: Artificial Intelligence'],
    ['SSEF', 2023, 'SUTD R&I Award: Aviation'],
    ['SSEF', 2023, 'SUTD R&I Award: Cities'],
    ['SSEF', 2023, 'SUTD R&I Award: Healthcare'],
    ['SSEF', 2023, 'SUTD R&I Award: Multi-Disciplinary'],
    ['SSEF', 2023, 'Yale-NUS Special Award'],
]

cur.executemany(sql, awards)
db.commit()

# %%
sql = "INSERT INTO Submission VALUES (%s, %s, %s, %s, %s)"

submissions = pd.read_csv("submissions.csv").fillna("").values.tolist()

cur.executemany(sql, submissions)
db.commit()

# %%
sql = "INSERT INTO Submits VALUES (%s, %s, %s, %s, %s)"

submits = pd.read_csv("submits.csv").fillna("").values.tolist()

cur.executemany(sql, submits)
db.commit()

# %%
sql = "INSERT INTO Accomplishment VALUES (%s, %s, %s, %s, %s, %s, %s)"

accs = pd.read_csv("accomplishments.csv").fillna("").values.tolist()

for i in accs[-3:]:
    i[-3:] = [None, None, None]

cur.executemany(sql, accs)
db.commit()

# %%
sql = "INSERT INTO Journal VALUES (%s, %s)"

journals = [
    (2663409, "The Physics Educator"),
    (13616404, "European Journal of Physics"),
    (15383881, "The Astronomical Journal"),
    (18614728, "Chemistry: An Asian Journal")
]

cur.executemany(sql, journals)
db.commit()

# %%
sql = "INSERT INTO PublishedBy VALUES (%s, %s)"

publishedBy = [
    (2663409, "IPS"),
    (2663409, "WS"),
    (13616404, "EPS"),
    (13616404, "IOP"),
    (15383881, "AAS"),
    (15383881, "IOP"),
    (18614728, "ACES"),
    (18614728, "WVCH")
]

cur.executemany(sql, publishedBy)
db.commit()

# %%
sql = "INSERT INTO Publication VALUES (%s, %s, %s, %s, %s, %s)"

publications = [
    (4, 
     "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms",
     "10.1007/978-981-16-9869-9_21",
     False, None, None
    ),
    (37,
     "An Investigation on the Aerodynamics of Flight of a Hand Helicopter",
     "10.1142/S2661339523500038",
     True,
     "https://www.worldscientific.com/doi/abs/10.1142/S2661339523500038",
     2663409
    ),
    (36,
     "Detecting Malware Samples using a Novel Feature Vector and Deep Learning Methods",
     "", False, None, None
    ),
    (38,
     "An Automated Screening System for Trinary Star System Candidates",
     "", True, "", 15383881
    ),
    (39,
    "Optically and Wirelessly Re-chargeable Buffer Batteries",
    "", True, "", 18614728
    )
]

cur.executemany(sql, publications)
db.commit()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Add in relevant select statements to show that your data is populated correctly FOR EACH relation, one cell each relation.
# </div>

# %%
# %%sql
# SELECT * FROM Institution
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 54 rows affected.
# [('AAS', 'American Astronomical Society', '1667 K Street NW, Suite 800, Washington, DC 20006 USA', 0, 0, 0, 1),
#  ('ACES', 'Asian Chemical Editorial Society', '', 0, 0, 0, 1),
#  ('ACJC', 'Anglo-Chinese Junior College', '25 Dover Cl E, Singapore 139745', 1, 0, 0, 0),
#  ('ACSI', 'Anglo-Chinese School (Independent)', '121 Dover Rd, Singapore 139650', 1, 0, 0, 0),
#  ('ASHK', 'The Academy of Sciences of Hong Kong', '10 Science Park W Ave, Science Park, Hong Kong', 0, 0, 1, 0),
#  ('ASRJC', 'Anderson Serangoon Junior College', '4500 Ang Mo Kio Ave 6, Singapore 569843', 1, 0, 1, 0),
#  ('ASTAR', 'Agency of Science, Technology and Research', '1 Fusionopolis Way, #20-10 Connexis, Singapore 138632', 0, 1, 1, 0),
#  ('BII', 'Bioinformatics Institute', '30 Biopolis St, Matrix, Singapore 138671', 0, 1, 0, 0),
#  ('CGSS', "Cedar Girls' School", '1 Cedar Ave, Singapore 349692', 1, 0, 0, 0),
#  ('DHS', 'Dunman High School', '10 Tg Rhu Rd, Singapore 436895', 1, 0, 0, 0),
#  ('DIGI', 'Digipen Institute of Technology', '510 Dover Rd, #03-01 SIT@SP, Building 139660', 0, 1, 0, 0),
#  ('DSO', 'Defence Science Organisation', '12 Science Park Drive, Singapore 118225', 0, 1, 0, 0),
#  ('DSTA', 'Defence Science and Technology Agency', '1 Depot Rd, Singapore 109679', 0, 1, 0, 0),
#  ('EJC', 'Eunoia Junior College', '2 Sin Ming Pl, Singapore 573838', 1, 0, 0, 0),
#  ('EPS', 'European Physical Society', '', 0, 0, 0, 1),
#  ('HCI', 'Hwa Chong Institution', '661 Bukit Timah Road, Singapore 269734', 1, 0, 1, 0),
#  ('HKFYG', 'Hong Kong Federation of Youth Groups', 'The Hong Kong Federation Of Youth Groups Building, 21 Pak Fuk Rd, Tsat Tsz Mui, Hong Kong', 0, 0, 1, 0),
#  ('IEEE', 'Institute of Electrical and Electronics Engineers', '445 and 501 Hoes Lane, Piscataway, NJ 08854-4141 USA', 0, 0, 1, 1),
#  ('IHPC', 'Institute of High Performance Computing', '1 Fusionopolis Way, #16-16 Connexis, Singapore 138632', 0, 1, 0, 0),
#  ('IIR', 'Institute for Infocomm Research', '1 Fusionopolis Way, #21-01 Connexis, Singapore 138632', 0, 1, 0, 0),
#  ('IMCB', 'Institute of Molecular and Cell Biology', '61 Biopolis Dr, Proteos, Singapore 138673', 0, 1, 0, 0),
#  ('IMRE', 'Institute of Materials Research and Engineering', '2 Fusionopolis Way, Singapore 138634', 0, 1, 0, 0),
#  ('IOP', 'IOP Publishing', '', 0, 0, 0, 1),
#  ('IPS', 'Institute of Physics Singapore', '2 Science Drive 3, Singapore 117542', 0, 0, 0, 1),
#  ('IRC', 'International Researchers Club', '511 Upper Jurong Rd, Singapore 638366', 0, 0, 1, 0),
#  ('MGS', "Methodist Girls' School", '11 Blackmore Dr, Singapore 599986', 1, 0, 0, 0),
#  ('NERI', 'NUS Environmental Research Institute', '5A Engineering Drive 1, #02-03 T-Lab Building, Singapore 117411', 0, 1, 0, 0),
#  ('NIE', 'National Institute of Education', '1 Nanyang Walk, Singapore 637616', 0, 1, 0, 0),
#  ('NJC', 'National Junior College', '37 Hillcrest Rd, Singapore 288913', 1, 0, 0, 0),
#  ('NSPC', 'NuSpace', 'Blk 71 Ayer Rajah Crescent, #05-21, Singapore 139951', 0, 1, 0, 0),
#  ('NTU', 'Nanyang Technological University', '50 Nanyang Ave, 639798', 0, 1, 0, 0),
#  ('NUH', 'National University Hospital', '5 Lower Kent Ridge Rd, Singapore 119074', 0, 1, 0, 0),
#  ('NUS', 'National University of Singapore', '21 Lower Kent Ridge Rd, Singapore 119077', 0, 1, 0, 1),
#  ('NYGH', "Nanyang Girls' High School", '2 Linden Dr, Singapore 288683', 1, 0, 0, 0),
#  ('RGS', "Raffles Girls' School", '2 Braddell Rise, Singapore 318871', 1, 0, 0, 0),
#  ('RI', 'Raffles Institution', '1 Raffles Institution Ln, Singapore 575954', 1, 1, 0, 0),
#  ('SAJC', "Saint Anthony's Junior College", '5 Sorby Adams Dr, Singapore 357691', 1, 0, 0, 0),
#  ('SCS', 'Science Centre Singapore', '15 Science Centre Rd, Singapore 609081', 0, 1, 1, 0),
#  ('SERI', 'Singapore Eye Research Institute', 'The Academia, 20 College Rd, Level 6 Discovery Tower, Singapore 169856', 0, 1, 0, 0),
#  ('SGH', 'Singapore General Hospital', '31 Third Hospital Ave, Singapore 168753', 0, 1, 0, 0),
#  ('SIT', 'Singapore Institute of Technology', '10 Dover Dr, Singapore 138683', 0, 1, 0, 0),
#  ('SJI', "Saint Joseph's Institution", '38 Malcolm Rd, Singapore 308274', 1, 0, 0, 0),
#  ('SMU', 'Singapore Management University', '81 Victoria St, Singapore 188065', 0, 1, 0, 0),
#  ('SP', 'Singapore Polytechnic', '500 Dover Rd, Singapore 139651', 1, 1, 0, 0),
#  ('SRIS', 'Skin Research Institute of Singapore', '11 Mandalay Rd, #17-01, Singapore 308232', 0, 1, 0, 0),
#  ('SUTD', 'Singapore University of Technology and Design', '8 Somapah Rd, Singapore 487372', 0, 1, 0, 0),
#  ('TJC', 'Temasek Junior College', '22 Bedok S Rd, Singapore 469278', 1, 0, 0, 0),
#  ('TLL', 'Temasek Life Sciences Laboratory', '1 Research Link National University of Singapore Singapore 117604', 0, 1, 0, 0),
#  ('VJC', 'Victoria Junior College', '20 Marine Vista, Singapore 449035', 1, 0, 0, 0),
#  ('VS', 'Victoria School', '2 Siglap Link, Singapore 448880', 1, 0, 0, 0),
#  ('WS', 'World Scientific Publishing', '5 Toh Tuck Link, Singapore 596224', 0, 0, 0, 1),
#  ('WVCH', 'Wiley-VCH', 'Boschstraße 12, 69469 Weinheim', 0, 0, 0, 1),
#  ('YIJC', 'Yishun Innova Junior College', '3 Yishun Ring Rd, Singapore 768675', 1, 0, 0, 0),
#  ('YLL', 'Yong Loo Lin School of Medicine', '10 Medical Dr, Singapore 117597', 0, 1, 0, 0)]

# %%
# %%sql
# SELECT * FROM Department
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 8 rows affected.
# [('BI', 'Biology'),
#  ('CM', 'Chemistry'),
#  ('CS', 'Computer Science'),
#  ('EL', 'English Language & Literature'),
#  ('HU', 'Humanities'),
#  ('MA', 'Mathematics & Statistics'),
#  ('PH', 'Physics & Engineering'),
#  ('RE', 'Research, Innovation and Enterprise')]

# %%
# %%sql
# SELECT * FROM NUSHTeacher
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 99 rows affected.
# [('anhs.chm@nushigh.edu.sg', 'Mr Chen Hong Ming', None, 0, 1, 'MA'),
#  ('anhsad@nushigh.edu.sg', 'Ms Ameryn Dahnia Bte Mohd Zaili', None, 0, 1, 'BI'),
#  ('anhsczm@nushigh.edu.sg', 'Mrs Chen Zhaoyan Madeline', None, 0, 1, 'HU'),
#  ('anhsevxm@nushigh.edu.sg', 'Ms Esther Vincent Xueming', None, 0, 0, 'EL'),
#  ('anhsipoh@nushigh.edu.sg', 'Ms Irene Poh', None, 0, 1, 'HU'),
#  ('anhsloh@nushigh.edu.sg', 'Mr Loh Ping Shun', None, 0, 1, 'HU'),
#  ('anhsrgoh@nushigh.edu.sg', 'Ms Rachel Goh Hui Qi', None, 0, 1, 'BI'),
#  ('nhsaj@nushigh.edu.sg', 'Mr Andre Jusuf', None, 1, 1, 'RE'),
#  ('nhsasri@nushigh.edu.sg', 'Ms Asrina Bte Sani', None, 0, 0, 'EL'),
#  ('nhsbd@nushigh.edu.sg', 'Ms Beji Dass', None, 0, 0, 'EL'),
#  ('nhsbrw@nushigh.edu.sg', 'Dr Bernard Ricardo Widjaja', None, 0, 1, 'PH'),
#  ('nhsbww@nushigh.edu.sg', 'Ms Bay Wee Wen', None, 0, 1, 'EL'),
#  ('nhscal@nushigh.edu.sg', 'Ms Chong Ai Lin', None, 0, 1, 'CM'),
#  ('nhscarol@nushigh.edu.sg', 'Ms Caroline Gordon', None, 0, 0, 'EL'),
#  ('nhscb@nushigh.edu.sg', 'Ms Chua Bann', None, 0, 1, 'HU'),
#  ('nhscesc@nushigh.edu.sg', 'Mr Claude Chua Eng Siong', None, 0, 1, 'CS'),
#  ('nhschany@nushigh.edu.sg', 'Mr Chan Yu Ming', None, 0, 1, 'MA'),
#  ('nhscjnr@nushigh.edu.sg', 'Ms Chan Jing-Ning Ruth', None, 0, 1, 'BI'),
#  ('nhsckyd@nushigh.edu.sg', 'Mr Chin Kiane Yun Dustin', None, 0, 0, 'EL'),
#  ('nhsclpm@nushigh.edu.sg', 'Ms Chin Lee Pyin Melissa', None, 0, 0, 'EL'),
#  ('nhscmh@nushigh.edu.sg', 'Mr Chai Ming Huang Royce', None, 1, 1, 'MA'),
#  ('nhscs@nushigh.edu.sg', 'Dr Chiam Sher-Yi', None, 1, 1, 'RE'),
#  ('nhscsp@nushigh.edu.sg', 'Ms Chew Shuhui Phylliscia', None, 0, 1, 'CS'),
#  ('nhscvl@nushigh.edu.sg', 'Mr Chia Vui Leong', None, 0, 1, 'MA'),
#  ('nhscyf@nushigh.edu.sg', 'Ms Cheong Yoke Fun', None, 0, 1, 'BI'),
#  ('nhscyz@nushigh.edu.sg', 'Ms Chan Yun-Zhi Eunice', None, 0, 0, 'EL'),
#  ('nhseftv@nushigh.edu.sg', 'Mr Eric Francis Tinsay Valles', None, 0, 0, 'EL'),
#  ('nhsfkc@nushigh.edu.sg', 'Ms Fong Kit Ching', None, 0, 1, 'BI'),
#  ('nhsfssf@nushigh.edu.sg', 'Dr Flora Soh Shu Fang', None, 0, 1, 'CM'),
#  ('nhsgsl@nushigh.edu.sg', 'Mr\xa0Goh Shu Liang', None, 0, 1, 'MA'),
#  ('nhshjhk@nushigh.edu.sg', 'Mr Ho Jun Hao Kenneth', None, 0, 1, 'PH'),
#  ('nhshs@nushigh.edu.sg', 'Dr Huang Sinong', None, 0, 1, 'BI'),
#  ('nhshxh@nushigh.edu.sg', 'Ms Huang Huan Xin', None, 0, 1, 'CM'),
#  ('nhsjhhj@nushigh.edu.sg', 'Mr Herman Chua Jia He', None, 0, 1, 'MA'),
#  ('nhsjz@nushigh.edu.sg', 'Ms\xa0Jiang Zewei Vivian', None, 0, 1, 'MA'),
#  ('nhskalpa@nushigh.edu.sg', 'Mrs Fernandez Kalpana', None, 0, 1, 'BI'),
#  ('nhskcm@nushigh.edu.sg', 'Mr Ku Ching Ming', None, 0, 1, 'MA'),
#  ('nhskey@nushigh.edu.sg', 'Mr Silas Yeem Kai Ean', None, 0, 1, 'PH'),
#  ('nhski@nushigh.edu.sg', 'Ms Ivy Koo', None, 0, 0, 'EL'),
#  ('nhskohm@nushigh.edu.sg', 'Ms Koh Mei Ying Genette', None, 0, 0, 'EL'),
#  ('nhsksb@nushigh.edu.sg', 'Ms Koh Siok Bee', None, 0, 1, 'CM'),
#  ('nhskyta@nushigh.edu.sg', 'Mr Alex Kwee Yeow Teck', None, 0, 1, 'HU'),
#  ('nhsladr@nushigh.edu.sg', 'Mr Lew Andrew Delfin Reyes', None, 0, 1, 'CM'),
#  ('nhslbc@nushigh.edu.sg', 'Mr Desmond Lim Beng Chong', None, 0, 1, 'PH'),
#  ('nhslch@nushigh.edu.sg', 'Mr Low Chin Han', None, 0, 1, 'MA'),
#  ('nhslcl@nushigh.edu.sg', 'Dr Lee Chan Lye', None, 0, 1, 'MA'),
#  ('nhslcs@nushigh.edu.sg', 'Mr Lim Chong Shen', None, 0, 0, 'EL'),
#  ('nhsld@nushigh.edu.sg', 'Mr Li Da', None, 0, 1, 'CS'),
#  ('nhsleesc@nushigh.edu.sg', 'Mr Lee Siak Cheong', None, 0, 1, 'BI'),
#  ('nhslic@nushigh.edu.sg', 'Ms Lim Ing Chieh Rebekah', None, 0, 1, 'HU'),
#  ('nhslimtc@nushigh.edu.sg', 'Mr Lim Teck Choow', None, 1, 1, 'MA'),
#  ('nhsljh@nushigh.edu.sg', 'Ms Lim Jia Hui', None, 0, 1, 'PH'),
#  ('nhsljyl@nushigh.edu.sg', 'Mr Lim Jun Yang Leonard', None, 0, 1, 'CS'),
#  ('nhslkh@nushigh.edu.sg', 'Mr Lee Kim Hun', None, 0, 1, 'CM'),
#  ('nhslkl@nushigh.edu.sg', 'Ms Loo Koh Lee', None, 0, 1, 'CM'),
#  ('nhsllc@nushigh.edu.sg', 'Ms Lim Li Chen', None, 0, 1, 'PH'),
#  ('nhslowkl@nushigh.edu.sg', 'Dr Low Kai Leng', None, 0, 1, 'BI'),
#  ('nhslqo@nushigh.edu.sg', 'Ms Ooi Liu Qi', None, 0, 1, 'MA'),
#  ('nhslsf@nushigh.edu.sg', 'Ms Lim Suat Fong Valerie', None, 0, 1, 'BI'),
#  ('nhslsh@nushigh.edu.sg', 'Ms Lee Sheau Huey', None, 0, 1, 'MA'),
#  ('nhslw@nushigh.edu.sg', 'Dr Li Wei', None, 0, 1, 'CM'),
#  ('nhslwls@nushigh.edu.sg', 'Ms Sofia Lau Wen Li', None, 0, 0, 'EL'),
#  ('nhslyh@nushigh.edu.sg', 'Mr Lim Yeow Heng', None, 0, 1, 'PH'),
#  ('nhsmjjp@nushigh.edu.sg', 'Dr Maury Julien Jean Pierre', None, 1, 1, 'CM'),
#  ('nhsmk@nushigh.edu.sg', 'Mr Murali Krishnaswamy', None, 0, 1, 'CM'),
#  ('nhsncl@nushigh.edu.sg', 'Mr Ng Chee Loong', None, 0, 1, 'CS'),
#  ('nhsnoh@nushigh.edu.sg', 'Ms Ng Oon Hui', None, 0, 1, 'BI'),
#  ('nhsnte@nushigh.edu.sg', 'Dr Ng Tiong Eng', None, 0, 1, 'PH'),
#  ('nhsnyr@nushigh.edu.sg', 'Ms Ng Yu Rui', None, 0, 1, 'CM'),
#  ('nhspbh@nushigh.edu.sg', 'Mr Poh Boon Hor', None, 0, 1, 'PH'),
#  ('nhsplp@nushigh.edu.sg', 'Ms Pek Lay Pheng', None, 0, 1, 'CM'),
#  ('nhsrg@nushigh.edu.sg', 'Mr Riduwan B Gafoor', None, 0, 1, 'PH'),
#  ('nhsrt@nushigh.edu.sg', 'Ms Renata Triani', None, 0, 1, 'BI'),
#  ('nhsscl@nushigh.edu.sg', 'Ms Joyce Seow Chwee Loon', None, 0, 1, 'MA'),
#  ('nhsskh@nushigh.edu.sg', 'Dr Seoh Kah Huat Robin', None, 0, 1, 'BI'),
#  ('nhssksc@nushigh.edu.sg', 'Mr Soh Kwan Seng Clifton', None, 0, 1, 'PH'),
#  ('nhssn@nushigh.edu.sg', 'Dr Seow Nianjia', None, 0, 1, 'CM'),
#  ('nhssy@nushigh.edu.sg', 'Mr Seow Yongli', None, 0, 1, 'PH'),
#  ('nhstags@nushigh.edu.sg', 'Mr Tan Guan Seng', None, 0, 1, 'PH'),
#  ('nhstbk@nushigh.edu.sg', 'Mr Tan Boon Keong', None, 0, 1, 'MA'),
#  ('nhstby@nushigh.edu.sg', 'Ms Tong Boon Yee', None, 0, 1, 'HU'),
#  ('nhstgh@nushigh.edu.sg', 'Ms Teo Geok Hon Sheryl', None, 0, 1, 'PH'),
#  ('nhsthc@nushigh.edu.sg', 'Dr Tang Hock Chun', None, 0, 1, 'BI'),
#  ('nhsthw@nushigh.edu.sg', 'Mr Wong Teck Hee', None, 0, 1, 'CM'),
#  ('nhstj@nushigh.edu.sg', 'Mr Joseph Tan Jit Bin', None, 0, 1, 'PH'),
#  ('nhstrf@nushigh.edu.sg', 'Mr Tan Rui Feng', None, 0, 1, 'MA'),
#  ('nhstsc@nushigh.edu.sg', 'Mrs Soong-Tan Seck Cher', None, 0, 1, 'CM'),
#  ('nhstsk@nushigh.edu.sg', 'Mr Tan Soon Kee @ Hariz Tan', None, 0, 1, 'PH'),
#  ('nhstyhj@nushigh.edu.sg', 'Mr\xa0Teoh Yeow Hwee Joel', None, 0, 1, 'MA'),
#  ('nhstyl@nushigh.edu.sg', 'Dr Teh Yun Ling', None, 0, 1, 'CM'),
#  ('nhstymg@nushigh.edu.sg', 'Mrs Khoo-Teo Yew Mei Grace', None, 0, 1, 'CM'),
#  ('nhswh@nushigh.edu.sg', 'Mr Wang Haibin', None, 0, 1, 'MA'),
#  ('nhswyl@nushigh.edu.sg', 'Ms\xa0Woo Yok Lin Verlyn', None, 0, 1, 'BI'),
#  ('nhsysy@nushigh.edu.sg', 'Mr Yeo Shyh Yuan Don', None, 0, 1, 'CM'),
#  ('nhsyw@nushigh.edu.sg', 'Ms Yenny Wijaya', None, 0, 1, 'PH'),
#  ('nhsyx@nushigh.edu.sg', 'Mrs Liu-Ye Xiajuan', None, 0, 1, 'MA'),
#  ('nhsyxh@nushigh.edu.sg', 'Mr Yuen Xiang Hao', None, 0, 1, 'PH'),
#  ('nhszj@nushigh.edu.sg', 'Ms Zhong Jingyi', None, 0, 1, 'CM'),
#  ('s.yuen@nushigh.edu.sg', 'Ms Yuen Lilin Sharalee', None, 0, 0, 'EL')]

# %%
# %%sql
# SELECT * FROM ExternalTeacher
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 3 rows affected.
# [('fong_shi_ning@moe.edu.sg', 'Ms Fong Shi Ning', 'TJC'),
#  ('goh.terence@dhs.edu.sg', 'Mr Terence Goh', 'DHS'),
#  ('LIM_Cheng_Xiang@schools.gov.sg', 'Lim Cheng Xiang', 'YIJC')]

# %%
# %%sql
# SELECT * FROM ExternalStudent
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 4 rows affected.
# [('ishneet_singh@temasekjc.moe.edu.sg', 'fong_shi_ning@moe.edu.sg'),
#  ('yau_le_qi@temasekjc.moe.edu.sg', 'fong_shi_ning@moe.edu.sg'),
#  ('lam.yikting@dhs.edu.sg', 'goh.terence@dhs.edu.sg'),
#  ('ashwin_lokesh@students.edu.sg', 'LIM_Cheng_Xiang@schools.gov.sg')]

# %%
# %%sql
# SELECT * FROM ResearchMentor
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 9 rows affected.
# [('arthurtay@nus.edu.sg', 'Arthur Tay'),
#  ('elie.hosry@singaporetech.edu.sg', 'Elie Hosry'),
#  ('hklim@smu.edu.sg', 'Lim How Khang'),
#  ('hoinok.tsao@nie.edu.sg', 'Tsao Hoi Nok'),
#  ('huangshaoying@sutd.edu.sg', 'Huang Shaoying'),
#  ('immanuel_koh@sutd.edu.sg', 'Immanuel Koh'),
#  ('rishabh_bhardwaj@mymail.sutd.edu.sg', 'Rishabh Bhardwaj'),
#  ('truonghuu.tram@singaporetech.edu.sg', 'Tram Truong-Huu'),
#  ('zning@nuspace.sg', 'Ng Zhen Ning')]

# %%
# %%sql
# SELECT * FROM Works_At
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 9 rows affected.
# [('arthurtay@nus.edu.sg', 'NUS', 'Electrical and Computer Engineering', 'Adjunct Professor', 'E4-08-12, 4 Engineering Drive 3, Singapore 117583'),
#  ('elie.hosry@singaporetech.edu.sg', 'DIGI', 'Computer Science', 'Principal Lecturer', None),
#  ('hklim@smu.edu.sg', 'SMU', 'Centre for Computational Law', 'Director', None),
#  ('hoinok.tsao@nie.edu.sg', 'NIE', 'Natural Sciences & Science Education', 'Assistant Professor', None),
#  ('huangshaoying@sutd.edu.sg', 'SUTD', 'Engineering Product Development', 'Assistant Professor', None),
#  ('immanuel_koh@sutd.edu.sg', 'SUTD', 'Architecture & Sustainable Design (ASD) and Design & Artificial Intelligence (DAI)', 'Assistant Professor', None),
#  ('rishabh_bhardwaj@mymail.sutd.edu.sg', 'SUTD', None, 'PhD Candidate', None),
#  ('truonghuu.tram@singaporetech.edu.sg', 'IIR', None, 'Computer Scientist', None),
#  ('truonghuu.tram@singaporetech.edu.sg', 'SIT', None, 'Assistant Professor', None)]

# %%
# %%sql
# SELECT * FROM Project
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 133 rows affected.
# [('20.022.NUSE.PH', "Gait Monitoring and Analysis for Parkinson's Disease Patients", 'Parkinson’s disease (PD) is a neurodegenerative disorder that affects the dopamine producing neurons in the substantia nigra, an area of the brain, l ... (942 characters truncated) ... rate at predicting FoG. Ultimately, a small and lightweight prototype was created based on acceleration data from accelerometers placed on the thigh.', None, 2021, 'PH', 'nhslyh@nushigh.edu.sg'),
#  ('21.029.SUTD.CS', 'Embodied AI for computational perception and understanding of spatial designs', 'Semantic Segmentation is a computer vision task used to identify specific regions of interest for virtual agents and autonomous robots or vehicles, s ... (754 characters truncated) ... ound that transfer learning with semantic segmentation is an effective way to comprehend the design and layouts of these HDB interiors and exteriors.', None, 2022, 'CS', 'nhsncl@nushigh.edu.sg'),
#  ('21.048.NSPC.PH', 'Optimization of the Telemetry, Tracking and Commmunications System in a CubeSat', 'The growing commercialisation of the space industry and novel developments in miniaturisation technology has led to an increase of adoption of Cube-S ... (604 characters truncated) ... ground station. Further bit-encoding and error correction is performed, resulting in a robust, efficient and simple means of Satellite image capture.', None, 2023, 'PH', 'nhsaj@nushigh.edu.sg'),
#  ('21.050.NSPC.PH', 'Implementation of an Electrical Power System on a 1U CubeSat', '', None, 2023, 'PH', 'nhsaj@nushigh.edu.sg'),
#  ('21.099.NUSH.MA', 'Gambler’s Ruin Problem and the Catalan Numbers', '', None, 2023, 'MA', 'nhslimtc@nushigh.edu.sg'),
#  ('21.108.NUSH.MA', 'Multiple Extensions of Circular Properties in Other Conic Sections', '', None, 2023, 'MA', 'nhsjz@nushigh.edu.sg'),
#  ('21.122.NUSC.CM', 'Performance Evaluation of Recycled Acyl-Modified Chitosan Filtration Membranes on Polluted Water Using Spectroscopic Techniques', 'Annual global crustacean shell waste amounts to 6-8 million tonnes, with 1.5 million in Southeast Asia. A novel method for designing membrane filters ... (1458 characters truncated) ... tes the potential of custom-modified chitosan membranes manufactured from eco-friendly sources as highly selective filters for water\xa0purification.', None, 2023, 'CM', 'nhstyl@nushigh.edu.sg'),
#  ('21.123.NUH_.BI', 'A Retrospective Colectomy Study on Post-operative Drain Use & Complications', '', None, 2023, 'BI', 'nhskalpa@nushigh.edu.sg'),
#  ('22.005.NUSH.BI', 'Quantification of Microplastics Bioaccumulation in Clam Using the Benchtop MALDI-TOF', '', None, 2023, 'BI', 'nhsnoh@nushigh.edu.sg'),
#  ('22.009.NUSH.PH', 'An Investigation on the Aerodynamics of Flight of a Hand Helicopter', 'A simple hand helicopter can be made by attaching rotor blades to one end of a vertical stick. The helicopter moves upwards when the stick is spun ab ... (718 characters truncated) ... al maximum height. The conditions required for the hand helicopter to fly stably are also investigated and explained using the Tennis Racket Theorem.', None, 2022, 'PH', 'nhstags@nushigh.edu.sg'),
#  ('22.011.NUSH.PH', 'Detecting and Simulating Stable Three-Body Systems', '', None, 2022, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('22.029.NERI.PH', 'Measuring pressure difference of air flow in the human nasal cavity with a physical 3D model', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.031.NERI.CM', 'Interactions between polyethylene and emerging organic contaminants, and its applications: adsorption in different mediums and effect of aging', '', None, 2023, 'CM', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.032.IMRE.CM', 'Solid State Materials for Energy Harvesting and Cooling: from Materials Synthesis, Characterization, and Analysis to Applications', '', None, 2023, 'CM', 'nhscal@nushigh.edu.sg'),
#  ('22.034.NUSP.PH', 'Laser-Transformed C-ZnTi as Luminous Photosensor', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.035.NUSH.MA', 'Weighted and Pure Dollar-Cost Averaging Strategies in Various Asset Classes', '', None, 2023, 'MA', 'nhscmh@nushigh.edu.sg'),
#  ('22.038.NTU_.PH', 'Modifying a 3D printer to function as a scanning microscope and drawing device', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.039.NUSB.BI', 'Understanding the Genetic Basis of Resistance to Combined Heat and Drought stress in Arabidopsis thaliana accessions response to heat and drought stress', '', None, 2023, 'BI', 'nhslsf@nushigh.edu.sg'),
#  ('22.040.NIE_.MA', 'Cultural adaptation of the dietary choice of international students living in boarding schools', '', None, 2023, 'MA', 'nhslimtc@nushigh.edu.sg'),
#  ('22.041.SMU_.MA', 'Legal Beagle: Law Classification and Identification App via Novel Deep Learning Graphical Neural Networks and Attention Networks', 'Law is very important to the public. People often do not have the time and/or the knowledge to conduct legal research by themselves. Consultation wit ... (1456 characters truncated) ... and finally the relevant acts that are related to the user’s case. This will all be packaged into a custom app to allow it to be accessible to users.', None, 2023, 'MA', 'nhslimtc@nushigh.edu.sg'),
#  ('22.042.SCS_.MA', 'On the Modification of Recursive Sequences of the form an = an-1 + an-j', '', None, 2023, 'MA', 'nhslimtc@nushigh.edu.sg'),
#  ('22.043.YLL_.BI', 'In Vitro Hemodynamic Assessment Model for Implantable Tricuspid Valve in a 3D Printed Human Heart with Fluid Dynamic Physiology in Cardio-pulmonary Bypass State', '', None, 2023, 'BI', 'nhscs@nushigh.edu.sg'),
#  ('22.044.YLL_.BI', 'Qualitative Cardioscopic Analysis of Tricuspid Valve Apparatus in a Semi-Pulsatile Fluid Dynamic Model', '', None, 2023, 'BI', 'nhscs@nushigh.edu.sg'),
#  ('22.045.NIE_.PH', 'Numerical Methods for Computation of Particles in Fusion Hot Spots', '', None, 2023, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('22.047.NUSC.CM', 'Growth and Crystallographic Characterisation of Beryllium Nitride Crystals as a Novel Semiconductor Material', '', None, 2023, 'CM', 'nhscal@nushigh.edu.sg'),
#  ('22.050.SUTD.CM', 'Construction of a Low-Energy Capacitive Deionisation Device for Effective Desalination', '', None, 2023, 'CM', 'nhsfssf@nushigh.edu.sg'),
#  ('22.051.NUSC.CM', 'First principles investigation of electronic structure, ligand field and magnetism of Re(III) compounds', '', None, 2023, 'CM', 'nhsmk@nushigh.edu.sg'),
#  ('22.052.NUS_.PH', 'Optimisation of the Design of an Electromagnetic Projectile Launcher', '', None, 2023, 'PH', 'nhsnte@nushigh.edu.sg'),
#  ('22.053.NUSE.CM', 'Investigating The Effects Of Microbiological Co-processing Of Food And Yard Waste To Modify Bioreactor\xa0Designs', '', None, 2023, 'CM', 'nhsksb@nushigh.edu.sg'),
#  ('22.054.IMRE.PH', 'Investigating the effects of hydrophilicity and heat on the exfoliation of WS2', '', None, 2023, 'PH', 'nhstsk@nushigh.edu.sg'),
#  ('22.055.IMRE.PH', 'Exploring the Electrical Characteristics of 2D Semiconductors for Quantum Computing', '', None, 2023, 'PH', 'nhsnte@nushigh.edu.sg'),
#  ('22.056.DSO_.CS', 'Real-World Implementation and Security Analysis of Structured Encryption on Amazon-Web Services', 'In this project, we build a structured encryption system for SQL databases which supports SELECT and JOIN queries. This system is implemented on Amaz ... (230 characters truncated) ...  full or partial information, and single or double-column setups), we rigorously show that our system is more resilient and secure than past schemes.', None, 2023, 'CS', 'nhsncl@nushigh.edu.sg'),
#  ('22.057.DSO_.PH', 'Reflectarray design based on rectangular pheonix cell', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.058.DSO_.CS', 'Explainable Video Analytics - A wide area multi-camera tracking perspective', '', None, 2023, 'CS', 'nhscesc@nushigh.edu.sg'),
#  ('22.059.DSO_.CS', 'Automated Scanning of Software Packages in Compiled Binaries', 'Vulnerabilities in open-source software pose dangers to users because malicious actors can exploit these vulnerabilities to compromise software secur ... (1453 characters truncated) ... nctions. This can be applied to other use cases such as discovering new vulnerabilities, improving the overall cybersecurity of open-source projects.', None, 2023, 'CS', 'nhscsp@nushigh.edu.sg'),
#  ('22.064.SIGN.BI', 'Nonlesional skin microbiome differs between children with atopic dermatitis (AD) and those with history of AD', '', None, 2023, 'BI', 'nhssn@nushigh.edu.sg'),
#  ('22.065.SIGN.BI', 'Sensitisation Profiles of House Dust Mite-allergic Subjects using an Allergen Microarray Platform', '', None, 2023, 'BI', 'nhssn@nushigh.edu.sg'),
#  ('22.066.NIE_.PH', 'Optically and Wirelessly Re-chargeable Buffer Batteries', 'Photocapacitors are a type of capacitors that can be wirelessly charged through exposure to electromagnetic radiation. This combines the functions of ... (1136 characters truncated) ... works. Sensitivity to infrared radiation allows usage in places impenetrable by visible light such as in internal organs and interior of electronics.', None, 2023, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('22.068.IMRE.PH', 'Evaluating RF Filter with Alternative Material as a Solution for 5g Mobile Applications', '', None, 2023, 'PH', 'nhstags@nushigh.edu.sg'),
#  ('22.069.SERI.PH', 'Development of photoluminescence imaging for perovskite solar cells', '', None, 2023, 'PH', 'nhslyh@nushigh.edu.sg'),
#  ('22.070.NTU_.CM', 'Power Supply System for Smart Contact Lens', '', None, 2023, 'CM', 'nhslw@nushigh.edu.sg'),
#  ('22.071.NIE_.HU', 'Procrastination Among University Students in Singapore: Its Relationships with Time Management and Emotional Regulation', '', None, 2023, 'HU', 'nhscs@nushigh.edu.sg'),
#  ('22.072.NTU_.BI', 'Development of new programmable RNA editing tools', '', None, 2023, 'BI', 'nhsrt@nushigh.edu.sg'),
#  ('22.073.NTU_.HU', 'Singapore Crypto-Linguistics: Deciphering the Singapore Stone', 'The Singapore Stone, discovered in 1819, was blown up in 1843 and remains an enigma today. Several studies have suggested the script to be Kawi, a Br ... (954 characters truncated) ... e two inscriptions are shown to share many stylistic similarities, suggesting that the Singapore Stone could be dated to the Later\xa0Kawi\xa0period.', None, 2023, 'HU', 'nhsbww@nushigh.edu.sg'),
#  ('22.074.IMRE.CM', 'Synthesis of mixed ligand MIL-53(Al) for defect engineering', '', None, 2023, 'CM', 'nhslw@nushigh.edu.sg'),
#  ('22.075.NUSC.CM', 'Changing Attitudes and Interest Levels Towards Organic Chemistry in High School Learners via a Digital Multiplayer Board Game', '', None, 2023, 'CM', 'nhstyl@nushigh.edu.sg'),
#  ('22.076.SUTD.HU', 'Young people’s preferences in movies: Evaluating the effectivess of movie ratings', '', None, 2023, 'HU', 'nhscs@nushigh.edu.sg'),
#  ('22.077.SUTD.PH', 'Shielding-Free Signal Noise Suppression in Portable Low-Field MRI', 'Portable Magnetic Resonance Imaging (poMRI) setups allow for point-of-care imaging, which can greatly enrich paramedic services. However, these setup ... (739 characters truncated) ... wing for on-the-spot calibration. Our noise suppression method might significantly improve the image quality of poMRI, without the need for a shield.', None, 2023, 'PH', 'nhssy@nushigh.edu.sg'),
#  ('22.078.IMRE.CM', 'Paper-based chemical sensors for food freshness monitoring', '', None, 2023, 'CM', 'nhsfssf@nushigh.edu.sg'),
#  ('22.079.SUTD.CS', 'Detecting Cyberbullying in Localised Text Messages using a Novel Classroom-Based Noisy Student Training Technique', '', None, 2023, 'CS', 'nhsncl@nushigh.edu.sg'),
#  ('22.084.NUSB.BI', 'Reliability of coral species identification for traceability in the aquarium trade', '', None, 2023, 'BI', 'nhshs@nushigh.edu.sg'),
#  ('22.085.SICS.BI', 'Investigating the association of antenatal mosquito-borne viral infections on pregnancy and child outcomes in Singapore', '', None, 2023, 'BI', 'nhsskh@nushigh.edu.sg'),
#  ('22.086.YLL_.BI', 'Optimising in vitro production of late stage Plasmodium falciparum gametocytes for Anopheles sinensis infection', '', None, 2023, 'BI', 'nhsthc@nushigh.edu.sg'),
#  ('22.087.CNGP.CS', 'Vessel Trajectory Prediction in Maritime Transportation based on deep learning', 'Precise Geolocation data of modern cargo ships allows us to precisely plot a ship’s trajectory. In conjunction with modern machine learning technique ... (1274 characters truncated) ... better as compared to TrAISformer. Across multiple datasets, we are consistently able to better predict maritime trajectory than\xa0previous\xa0work.', None, 2023, 'CS', 'nhsld@nushigh.edu.sg'),
#  ('22.088.YLL_.RE', 'Prevalence of Allergies in Singaporean Teens', '', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('22.089.YLL_.BI', 'Investigating the role of ECSIT on gastric cancer', '', None, 2023, 'BI', 'nhsrt@nushigh.edu.sg'),
#  ('22.090.SRIS.BI', 'Effect of Animal Extract on Wound Healing in 3T3 Fibroblasts\u200b', '', None, 2023, 'BI', 'nhslsf@nushigh.edu.sg'),
#  ('22.091.NUSB.BI', 'Analysing Environmental Influences on the Plant Diversity of a Naturalised Plot', '', None, 2023, 'BI', 'nhshs@nushigh.edu.sg'),
#  ('22.092.NUSH.MA', 'Representing Royal Families using Graph Theory', 'Historians studying mediaeval royal families have faced challenges understanding the chaotic dynamics of the family trees. This has made research in  ... (1238 characters truncated) ... ld form the foundation for future more complex and flexible formulas, and thus is a step closer to describing what seemed to be a chaotic phenomenon.', None, 2023, 'MA', 'nhswh@nushigh.edu.sg'),
#  ('22.095.NUSE.CS', 'Regressing thyromental distance based on real time 3D reconstruction of the face mesh', 'During the pandemic, the pressures on the healthcare industry have greatly increased, with hospitals running low on resources and manpower. A common  ... (1157 characters truncated) ... ng input faces as combinations (of hundreds) of stored 3D models. We generated our own synthetic data using flame and trained our data based on that.', None, 2023, 'CS', 'nhspbh@nushigh.edu.sg'),
#  ('22.096.NUH_.BI', 'Investigating sputum CD62L levels in clinical asthma of varying severity', '', None, 2023, 'BI', 'nhscjnr@nushigh.edu.sg'),
#  ('22.097.YLL_.BI', 'Enhanced antibacterial activity of a novel phage-antibiotic combination against Klebsiella pneumoniae isolates', 'Klebsiella pneumoniae is a highly prevalent, multi-drug resistant pathogen which is associated with high morbidity and mortality rates due to the lim ... (1280 characters truncated) ... of our novel phage-antibiotic cocktail in treating K. pneumoniae infections in patients who do not respond to conventional antibiotic\xa0therapy.\xa0', None, 2023, 'BI', 'nhsthc@nushigh.edu.sg'),
#  ('22.099.NUSC.CM', 'Using FTIR to investigate plastic degradation by white rot fungi ', '', None, 2023, 'CM', 'nhstyl@nushigh.edu.sg'),
#  ('22.100.NTU_.RE', 'Multimodal assessment and coaching feedback to improve Public Speaking performance', '', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('22.101.IMRE.PH', 'Infrared Laser Locking to Rubidium Saturated Absorption Spectrum', '', None, 2023, 'PH', 'nhspbh@nushigh.edu.sg'),
#  ('22.102.SUTD.RE', 'A flexible platform for music composition AI', '', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('22.103.NUSB.BI', 'Potential Factors influencing Local Butterfly Biodiversity in Park Connectors', '', None, 2023, 'BI', 'nhslsf@nushigh.edu.sg'),
#  ('22.104.IHPC.RE', 'Neurocognitive Functioning and School Performance in Students With Special Educational Needs', '', None, 2023, 'RE', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.105.DSO_.PH', 'The bird in the swarm: how to detect and resolve closely-spaced targets in radar', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.106.YLL_.BI', 'Investigating the Gal-3 rs4644 Single Nucleotide Polymorphisms effects on CaV-1.2 Calcium Channels in Hypertension ', '', None, 2023, 'BI', 'nhshs@nushigh.edu.sg'),
#  ('22.107.NUSG.CS', 'Interpreting and Evading Visualization-Based Deep Learning Malware Classifiers', 'Machine learning has seen increasing usage in the field of cybersecurity, particularly for the classification of malware. Visualization-based techniq ... (1146 characters truncated) ... tion-based deep learning classifiers due to low interpretability and ease of evasion, contrary to recent research output which claims its robustness.', None, 2023, 'CS', 'nhscesc@nushigh.edu.sg'),
#  ('22.109.NUSC.CM', 'Purifying Nanoplastic-Contaminated Water with Functionalised Cellulose Extracted from Lychee Peels', '', None, 2023, 'CM', 'nhsmk@nushigh.edu.sg'),
#  ('22.111.NUSH.MA', 'Mutating Speed of Viruses', '', None, 2023, 'MA', 'nhsyx@nushigh.edu.sg'),
#  ('22.112.NUSH.MA', 'En Bloc Buildings Scientifically', '', None, 2023, 'MA', 'nhsyx@nushigh.edu.sg'),
#  ('22.113.NUSH.MA', 'Exploring the Maximum Area of Triangles Inscribed in Various Conic Sections', '', None, 2023, 'MA', 'nhsjz@nushigh.edu.sg'),
#  ('22.114.NUSH.MA', 'Exploring the maximum volume and surface area of polyhedra inscribed in a sphere', '', None, 2023, 'MA', 'nhsjz@nushigh.edu.sg'),
#  ('22.115.NUSH.MA', 'Chromatic Number of Graph Powers', '', None, 2023, 'MA', 'nhslcl@nushigh.edu.sg'),
#  ('22.116.NUSH.MA', 'On Ramsey Numbers and Monochromatic Cliques in a Complete Graph', '', None, 2023, 'MA', 'nhslcl@nushigh.edu.sg'),
#  ('22.118.NUSH.MA', 'A Computational Approach to Modelling Medieval Royal Families', '', None, 2023, 'MA', 'nhswh@nushigh.edu.sg'),
#  ('22.119.NUSH.MA', 'Development of a clear-cut and adaptable coding system for taxonomic classification based on numeric strings', '', None, 2023, 'MA', 'nhswh@nushigh.edu.sg'),
#  ('22.120.NERI.BI', 'Investigating the Prevalence and Antibiotic Resistance of Klebsiella pneumoniae in Surface Water: An Antibiotic Resistance Profiling and Risk Assessment\xa0Study', '', None, 2023, 'BI', 'nhslowkl@nushigh.edu.sg'),
#  ('22.122.NUSC.CM', 'Characterisation and correlations of free fatty acid compositions of cooking oils with Heme-mediated lipid peroxidation reactions', '', None, 2023, 'CM', 'nhsksb@nushigh.edu.sg'),
#  ('22.123.BII_.CM', 'Deep Learning Model for the Prediction of Antimicrobial Agents', "In the face of increasing antimicrobial resistance, antimicrobial peptides (AMPs) have shown great potential as an alternative method to kill or inhi ... (793 characters truncated) ... rain at or above 70\\% confidence level. In future work, we hope to do wet-lab testing to determine the actual efficacy of the suggested\xa0peptides.", None, 2023, 'CM', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.124.NTU_.PH', 'Interactions between Vortex Rings and Solid Boundaries', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.125.NUSE.CM', 'Self Healing of Concrete with Recycled Concrete Aggregates', '', None, 2023, 'CM', 'nhssn@nushigh.edu.sg'),
#  ('22.126.NUSH.MA', 'Approaching Hadwiger’s Conjecture using List Coloring', '', None, 2023, 'MA', 'nhslcl@nushigh.edu.sg'),
#  ('22.127.NUSB.BI', 'A comparison of the livability of two habitats using butterflies as an ecological indicator as well as the effectiveness of different butterfly baits and traps', '', None, 2023, 'BI', 'nhslsf@nushigh.edu.sg'),
#  ('22.129.NUSA.CM', 'Synthesis of Peptide Nanomaterials via Controlled Self-Assembly', '', None, 2023, 'CM', 'nhssn@nushigh.edu.sg'),
#  ('22.131.IMRE.CM', 'Thermoelectrics for Converting Heat into Electricity and Solid-state Refrigeratio', '', None, 2023, 'CM', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.132.NUSH.MA', 'Math project using data from gov.sg (Minh Thai)  ', '', None, 2023, 'MA', 'nhsyx@nushigh.edu.sg'),
#  ('22.133.NUSB.BI', 'Novel Primary Data Collection and Classification of Microplastics in Coastal Waters of Singapore for Research Usage', '', None, 2023, 'BI', 'nhscjnr@nushigh.edu.sg'),
#  ('22.134.LKCS.BI', 'Tuning T-lymphocytes to improve wound healing', '', None, 2023, 'BI', 'nhscjnr@nushigh.edu.sg'),
#  ('22.135.IHPC.BI', 'Effect of different genres of music on food perception ', '', None, 2023, 'BI', 'nhsnoh@nushigh.edu.sg'),
#  ('22.137.DIGI.CS', 'LEDA: A Lightweight Game Engine using C++ Component-Based Techniques', 'Game engines are tools commonly used by software developers to create dynamic applications, containing ready-made functions that clients can use. How ... (1236 characters truncated) ... ible option for newer developers who are beginning to create their own applications without being intimidated by larger, commercial-use game engines.', None, 2023, 'CS', 'nhscsp@nushigh.edu.sg'),
#  ('22.138.NUSP.PH', 'Light scattering of micro objects', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.139.NUSP.PH', 'Fundamentals of Precision Ellipsometry ', '', None, 2023, 'PH', 'nhscs@nushigh.edu.sg'),
#  ('22.140.NUSC.CM', 'The Effect of Different Storage Conditions on Fruit Peels for the Green Synthesis of Silver Nanoparticles', '', None, 2023, 'CM', 'nhsfssf@nushigh.edu.sg'),
#  ('22.141.NUSH.CS', 'Longest simple path with Machine Learning', 'The longest simple path problem on general undirected graphs is a well-studied NP-Complete problem. It has applications in circuit board design, robo ... (631 characters truncated) ...  on our testing dataset and the graph neural network was able to perform better than some of the best algorithms that were done\xa0in\xa0the\xa0past.', None, 2023, 'CS', 'nhsncl@nushigh.edu.sg'),
#  ('22.142.NUSH.CS', 'Deep Equilibrium BERT', 'Deep Equilibrium Models (DEQ) are a class of implicit neural networks that have recently gained attention due to their competitive performance agains ... (699 characters truncated) ... odel encourages further exploration and improvement of DEQ language models. All source code can be found at github.com/Clyde013/DeepEquilibrium-BERT.', None, 2023, 'CS', 'nhscesc@nushigh.edu.sg'),
#  ('22.143.NUSH.CM', 'Application of water hyacinth as a low-cost biosorbent for dyes in textile wastewater', '', None, 2023, 'CM', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.144.NUSB.RE', 'Ecological Footprint of Smallholder vs Industrial Oil Palm Plantations in Indonesia', '', None, 2023, 'RE', 'anhsczm@nushigh.edu.sg'),
#  ('22.147.NUSC.CM', 'Enantioselective synthesis of biaryl atropisomers from Suzuki-Miyaura reaction using ionic interactions', '', None, 2023, 'CM', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.149.NUSC.CM', 'The effect of fluidizers on the structure and dynamics of live cell membranes studied by single molecule fluorescence microscopy', '', None, 2023, 'CM', 'nhsnyr@nushigh.edu.sg'),
#  ('22.151.NUSH.MA', 'Algebraic solutions to extensions of Apollonius’ problem in 3D', 'The Apollonius’ problem in 2D involves finding circles that are tangent to three given objects. This problem has been studied extensively for centuri ... (1639 characters truncated) ... he specific geometry of the objects involved. In some cases, it is possible to achieve perfect packing, while in others, significant gaps may remain.', None, 2023, 'MA', 'nhsjz@nushigh.edu.sg'),
#  ('22.152.NUSH.MA', 'Inequality and Retail Sales', '', None, 2023, 'MA', 'nhswh@nushigh.edu.sg'),
#  ('22.154.NUSH.MA', 'E-commerce during the pandemic: Last-mile delivery leveraging autonomous vehicles', '', None, 2023, 'MA', 'nhscmh@nushigh.edu.sg'),
#  ('22.155.IMCB.BI', 'Developing an Optogenetic O-GlcNAc Transferase for Single Protein O-GlcNAcylation in Cells', '', None, 2023, 'BI', 'nhsmjjp@nushigh.edu.sg'),
#  ('22.156.NUSH.RE', 'Tilapia Feed', '', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('22.157.NUSH.BI', 'Human Disturbances and its Effects on Bird Diversity in Lakeside Garden', '', None, 2023, 'BI', 'nhscs@nushigh.edu.sg'),
#  ('23.001.NUSH.MA', 'Dungeons and Dragons Inspired Cantrip Knockout Prediction: Error-mimimising Numerical Investigative Study', '', None, 2023, 'MA', 'nhscmh@nushigh.edu.sg'),
#  ('23.002.NUSH.BI', 'How do composts made from banana peels, apple peels and orange peels affect the growth of a plant?', '', None, 2023, 'BI', 'nhsskh@nushigh.edu.sg'),
#  ('23.003.NUSH.BI', 'Pleurotus Ostreatus growth in Barley-cardboard substrate in soil', '', None, 2023, 'BI', 'nhsskh@nushigh.edu.sg'),
#  ('23.006.NSPC.PH', 'Image Capture System for a Nanosatellite', '', None, 2023, 'PH', 'nhsaj@nushigh.edu.sg'),
#  ('23.007.NUSH.CS', 'Low Dose, High Accuracy: Using Deep Learning to Enhance 3D Tomography', 'Computed tomography is a imaging technique that makes use of particles such as x-ray photons to examine the interiors of objects. It has become an in ... (994 characters truncated) ... sages, with our model achieving a peak-signal-to-noise-ratio of 32.24 and structural similarity index of 0.781 even when 90% of sinograms are masked.', None, 2023, 'CS', 'nhsncl@nushigh.edu.sg'),
#  ('23.009.TLL_.BI', 'Analysis Of callus Growth of Various Species of Plants in Mediums with Cytokinins and Auxins under Differing Light Conditions', '', None, 2023, 'BI', 'nhslsf@nushigh.edu.sg'),
#  ('23.010.SIT_.CS', 'Detecting Malware Samples using a Novel Feature Vector and Deep Learning Methods', 'Dynamic malware analysis, which has been a major field in malware analysis, involves executing the malware in a controlled environment and observing  ... (858 characters truncated) ...  that our solution outperforms many baseline state-of-the-art malware detectors, therefore proving the effectiveness of our feature vector and model.', None, 2023, 'CS', 'nhsld@nushigh.edu.sg'),
#  ('23.011.SGH_.CS', 'Deep learning model for the diagnosis of exudative pharyngitis', 'Background: Telemedicine is firmly established in the healthcare landscape of many countries. Acute respiratory infection is the most common reason f ... (1384 characters truncated) ... learning for the diagnosis of exudative pharyngitis. I have deployed the model on a web application for automated diagnosis of exudative pharyngitis.', None, 2023, 'CS', 'nhscsp@nushigh.edu.sg'),
#  ('23.012.NUSB.BI', 'Heterologous Expression of Avicennia Officinalis Cation-Chloride Cotransporter (CCC1) In Arabidopsis and Yeast and It’s Role in the Regulation Of Salt Tolerance', '', None, 2023, 'BI', 'nhshs@nushigh.edu.sg'),
#  ('23.013.NUSH.PH', 'A Cost-Effective and Accessible Construction of Ground Station for CubeSat Applications', '', None, 2023, 'PH', 'nhsaj@nushigh.edu.sg'),
#  ('23.015.NUSB.BI', 'Hunting for Bacteriophages', '', None, 2023, 'BI', 'nhshs@nushigh.edu.sg'),
#  ('23.016.NUSH.MA', 'On the Application of Inequalities Containing Sums of Minimum/Maximum of Numbers', '', None, 2023, 'MA', 'nhswh@nushigh.edu.sg'),
#  ('23.017.NUSH.PH', 'On the Vibroacoustic Modelling of Tensioned Elastic Membranes in a Pressurised Air Cavity', '', None, 2023, 'PH', 'nhslyh@nushigh.edu.sg'),
#  ('23.018.NUSH.CS', "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms", 'Parkinson’s Disease (PD) is a neurodegenerative disease that affects the substantia nigra, a region in the brain. It causes many hindrances to activi ... (1031 characters truncated) ... ck freeze events over a period of time. This can help doctors diagnose patients and gauge the severity of the disease, so as to prescribe medication.', None, 2023, 'CS', 'nhslimtc@nushigh.edu.sg'),
#  ('23.019.NUSH.PH', 'Three Dimensional Modelling of the Maximum Fluid Load on a Horizontally Rotating Cylinder', 'It is a well-known fact that when a rod coated with a viscous liquid such as honey is rotated at a sufficiently high speed, the liquid will stop drai ... (595 characters truncated) ... imulations. Afterwards, this is used to plot a phase plot of the phase of the fluid at a certain point in time which is also experimentally verified.', None, 2023, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('23.020.NUSH.PH', 'Numerical Simulation of Small Floating Particles on a Fluid Surface under the Influence of a Magnetic Field', "It has been observed that floating particles on a liquid surface will move when exposed to a magnetic field. While previous literature has identified ... (595 characters truncated) ... n, accounting for the particle's mutual attraction due to the Cheerios effect. Our theoretical predictions then compared to our experimental results.", None, 2023, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('23.021.NUSH.PH', 'Theoretical and Experimental Analysis into the Accuracy of the Rayleigh Disk', 'This work aims to investigate into the Rayleigh disk, a simple device used for measuring the intensity of acoustic fields. The Rayleigh disk refers t ... (915 characters truncated) ... . The findings presented in this work help us to gain a deeper understanding of how the Rayleigh disk functions and its accuracy as a practical tool.', None, 2023, 'PH', 'nhstags@nushigh.edu.sg'),
#  ('23.029.NUSH.RE', 'Investigating the effect of colours on Medical Facilities', '', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('23.030.NUSH.PH', 'An Automated Screening System for Trinary Star System Candidates', 'The discovery and cataloguing of trinary star systems is of significant interest to the field of astronomy, with implications from stellar system for ... (847 characters truncated) ... ation of trinary stars. Our classification of the dataset, alongside all source code, is available at https://github.com/three-body-analysis/codebase', None, 2023, 'PH', 'nhsbrw@nushigh.edu.sg'),
#  ('23.031.IMCB.RE', 'Active matter cytometry for high-resolution sizing, sorting of zebrafish larvae', 'In aquaculture farming, uneven larval growth is often observed and sorting at the early stages is necessary to prevent cannibalism and uneven product ... (1128 characters truncated) ... sing component, we can also utilize our design for high-quality imaging of larvae and make use of machine learning for other classification criteria.', None, 2023, 'RE', 'nhscs@nushigh.edu.sg'),
#  ('23.032.NUSH.HU', 'Consumer attitudes towards local produce', '', None, 2023, 'HU', 'nhscs@nushigh.edu.sg'),
#  ('23.033.NUSH.HU', "Student's behaviour in canteen choices ", '', None, 2023, 'HU', 'nhsyw@nushigh.edu.sg'),
#  ('23.036.IBB_.BI', 'Optimization of logic gates for one-step detection of microRNAs via Split loop-mediated isothermal amplification (Split-LAMP)', '', None, 2023, 'BI', 'nhskalpa@nushigh.edu.sg'),
#  ('23.038.NUSH.PH', 'Investigation of a fair three sided dice', '', None, 2023, 'PH', 'nhsnte@nushigh.edu.sg')]

# %%
# %%sql
# SELECT * FROM Works_On
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 295 rows affected.
# [('h1810111@nushigh.edu.sg', '20.022.NUSE.PH'),
#  ('h1810124@nushigh.edu.sg', '20.022.NUSE.PH'),
#  ('h1810167@nushigh.edu.sg', '20.022.NUSE.PH'),
#  ('h1810068@nushigh.edu.sg', '21.029.SUTD.CS'),
#  ('h1810124@nushigh.edu.sg', '21.029.SUTD.CS'),
#  ('h1810104@nushigh.edu.sg', '21.048.NSPC.PH'),
#  ('h1810124@nushigh.edu.sg', '21.048.NSPC.PH'),
#  ('h1810053@nushigh.edu.sg', '21.050.NSPC.PH'),
#  ('h2030011@nushigh.edu.sg', '21.050.NSPC.PH'),
#  ('h1710122@nushigh.edu.sg', '21.099.NUSH.MA'),
#  ('h1910157@nushigh.edu.sg', '21.108.NUSH.MA'),
#  ('h1810015@nushigh.edu.sg', '21.122.NUSC.CM'),
#  ('h1810075@nushigh.edu.sg', '21.122.NUSC.CM'),
#  ('h1810151@nushigh.edu.sg', '21.122.NUSC.CM'),
#  ('h1810073@nushigh.edu.sg', '21.123.NUH_.BI'),
#  ('h1810108@nushigh.edu.sg', '22.005.NUSH.BI'),
#  ('h2030005@nushigh.edu.sg', '22.005.NUSH.BI'),
#  ('h1810084@nushigh.edu.sg', '22.009.NUSH.PH'),
#  ('h1810038@nushigh.edu.sg', '22.011.NUSH.PH'),
#  ('h1810124@nushigh.edu.sg', '22.011.NUSH.PH'),
#  ('h1810159@nushigh.edu.sg', '22.011.NUSH.PH'),
#  ('h1810166@nushigh.edu.sg', '22.011.NUSH.PH'),
#  ('h1810019@nushigh.edu.sg', '22.029.NERI.PH'),
#  ('h1810058@nushigh.edu.sg', '22.029.NERI.PH'),
#  ('h1810165@nushigh.edu.sg', '22.029.NERI.PH'),
#  ('h1810057@nushigh.edu.sg', '22.031.NERI.CM'),
#  ('h1810094@nushigh.edu.sg', '22.031.NERI.CM'),
#  ('h1810136@nushigh.edu.sg', '22.031.NERI.CM'),
#  ('h1910049@nushigh.edu.sg', '22.032.IMRE.CM'),
#  ('h1710026@nushigh.edu.sg', '22.034.NUSP.PH'),
#  ('h1810033@nushigh.edu.sg', '22.034.NUSP.PH'),
#  ('h1810093@nushigh.edu.sg', '22.034.NUSP.PH'),
#  ('h1810089@nushigh.edu.sg', '22.035.NUSH.MA'),
#  ('h1810121@nushigh.edu.sg', '22.035.NUSH.MA'),
#  ('h1910074@nushigh.edu.sg', '22.038.NTU_.PH'),
#  ('h1910118@nushigh.edu.sg', '22.038.NTU_.PH'),
#  ('h1910129@nushigh.edu.sg', '22.038.NTU_.PH'),
#  ('h2010042@nushigh.edu.sg', '22.039.NUSB.BI'),
#  ('h2010089@nushigh.edu.sg', '22.039.NUSB.BI'),
#  ('h2010129@nushigh.edu.sg', '22.039.NUSB.BI'),
#  ('h1910023@nushigh.edu.sg', '22.040.NIE_.MA'),
#  ('h1910125@nushigh.edu.sg', '22.040.NIE_.MA'),
#  ('h1910059@nushigh.edu.sg', '22.041.SMU_.MA'),
#  ('h1910099@nushigh.edu.sg', '22.041.SMU_.MA'),
#  ('h1910153@nushigh.edu.sg', '22.041.SMU_.MA'),
#  ('h1910016@nushigh.edu.sg', '22.042.SCS_.MA'),
#  ('h1910064@nushigh.edu.sg', '22.042.SCS_.MA'),
#  ('h1910157@nushigh.edu.sg', '22.042.SCS_.MA'),
#  ('h1810027@nushigh.edu.sg', '22.043.YLL_.BI'),
#  ('h1810067@nushigh.edu.sg', '22.043.YLL_.BI'),
#  ('h1810169@nushigh.edu.sg', '22.043.YLL_.BI'),
#  ('h1810109@nushigh.edu.sg', '22.044.YLL_.BI'),
#  ('h2030001@nushigh.edu.sg', '22.044.YLL_.BI'),
#  ('h1810110@nushigh.edu.sg', '22.045.NIE_.PH'),
#  ('h1810132@nushigh.edu.sg', '22.045.NIE_.PH'),
#  ('h1810142@nushigh.edu.sg', '22.045.NIE_.PH'),
#  ('h1810145@nushigh.edu.sg', '22.047.NUSC.CM'),
#  ('h1810147@nushigh.edu.sg', '22.047.NUSC.CM'),
#  ('h2010025@nushigh.edu.sg', '22.050.SUTD.CM'),
#  ('h2010077@nushigh.edu.sg', '22.050.SUTD.CM'),
#  ('h2010164@nushigh.edu.sg', '22.050.SUTD.CM'),
#  ('h1910091@nushigh.edu.sg', '22.051.NUSC.CM'),
#  ('h1910113@nushigh.edu.sg', '22.051.NUSC.CM'),
#  ('h1910126@nushigh.edu.sg', '22.051.NUSC.CM'),
#  ('h1910040@nushigh.edu.sg', '22.052.NUS_.PH'),
#  ('h1910136@nushigh.edu.sg', '22.052.NUS_.PH'),
#  ('h2130010@nushigh.edu.sg', '22.052.NUS_.PH'),
#  ('h1810022@nushigh.edu.sg', '22.053.NUSE.CM'),
#  ('h1810092@nushigh.edu.sg', '22.053.NUSE.CM'),
#  ('h1810043@nushigh.edu.sg', '22.054.IMRE.PH'),
#  ('h1810088@nushigh.edu.sg', '22.054.IMRE.PH'),
#  ('h1810144@nushigh.edu.sg', '22.054.IMRE.PH'),
#  ('h1810003@nushigh.edu.sg', '22.055.IMRE.PH'),
#  ('h1810017@nushigh.edu.sg', '22.055.IMRE.PH'),
#  ('h1810141@nushigh.edu.sg', '22.055.IMRE.PH'),
#  ('h1810084@nushigh.edu.sg', '22.056.DSO_.CS'),
#  ('h1810070@nushigh.edu.sg', '22.057.DSO_.PH'),
#  ('h1910090@nushigh.edu.sg', '22.058.DSO_.CS'),
#  ('h1910158@nushigh.edu.sg', '22.058.DSO_.CS'),
#  ('h1810055@nushigh.edu.sg', '22.059.DSO_.CS'),
#  ('h1810139@nushigh.edu.sg', '22.059.DSO_.CS'),
#  ('h1810014@nushigh.edu.sg', '22.064.SIGN.BI'),
#  ('h1810040@nushigh.edu.sg', '22.064.SIGN.BI'),
#  ('h1810016@nushigh.edu.sg', '22.065.SIGN.BI'),
#  ('h1810026@nushigh.edu.sg', '22.065.SIGN.BI'),
#  ('h1810107@nushigh.edu.sg', '22.065.SIGN.BI'),
#  ('h1810053@nushigh.edu.sg', '22.066.NIE_.PH'),
#  ('h1810137@nushigh.edu.sg', '22.066.NIE_.PH'),
#  ('h1810031@nushigh.edu.sg', '22.068.IMRE.PH'),
#  ('h1810013@nushigh.edu.sg', '22.069.SERI.PH'),
#  ('h1810034@nushigh.edu.sg', '22.069.SERI.PH'),
#  ('h1810154@nushigh.edu.sg', '22.069.SERI.PH'),
#  ('h1810090@nushigh.edu.sg', '22.070.NTU_.CM'),
#  ('h1810027@nushigh.edu.sg', '22.071.NIE_.HU'),
#  ('h1810047@nushigh.edu.sg', '22.072.NTU_.BI'),
#  ('h1810075@nushigh.edu.sg', '22.073.NTU_.HU'),
#  ('h1810050@nushigh.edu.sg', '22.074.IMRE.CM'),
#  ('h1810061@nushigh.edu.sg', '22.075.NUSC.CM'),
#  ('h1810073@nushigh.edu.sg', '22.075.NUSC.CM'),
#  ('h1810123@nushigh.edu.sg', '22.075.NUSC.CM'),
#  ('h1810037@nushigh.edu.sg', '22.076.SUTD.HU'),
#  ('h1810115@nushigh.edu.sg', '22.076.SUTD.HU'),
#  ('h1810166@nushigh.edu.sg', '22.077.SUTD.PH'),
#  ('h2030008@nushigh.edu.sg', '22.077.SUTD.PH'),
#  ('h1810044@nushigh.edu.sg', '22.078.IMRE.CM'),
#  ('h1810130@nushigh.edu.sg', '22.078.IMRE.CM'),
#  ('h1810068@nushigh.edu.sg', '22.079.SUTD.CS'),
#  ('h1810124@nushigh.edu.sg', '22.079.SUTD.CS'),
#  ('h1910059@nushigh.edu.sg', '22.079.SUTD.CS'),
#  ('h1810002@nushigh.edu.sg', '22.084.NUSB.BI'),
#  ('h1810163@nushigh.edu.sg', '22.084.NUSB.BI'),
#  ('h2030013@nushigh.edu.sg', '22.084.NUSB.BI'),
#  ('h1810012@nushigh.edu.sg', '22.085.SICS.BI'),
#  ('h1810155@nushigh.edu.sg', '22.085.SICS.BI'),
#  ('h1810005@nushigh.edu.sg', '22.086.YLL_.BI'),
#  ('h1810030@nushigh.edu.sg', '22.086.YLL_.BI'),
#  ('h1810082@nushigh.edu.sg', '22.086.YLL_.BI'),
#  ('h1810004@nushigh.edu.sg', '22.087.CNGP.CS'),
#  ('h1810129@nushigh.edu.sg', '22.087.CNGP.CS'),
#  ('h2030002@nushigh.edu.sg', '22.087.CNGP.CS'),
#  ('h1810007@nushigh.edu.sg', '22.088.YLL_.RE'),
#  ('h1810064@nushigh.edu.sg', '22.088.YLL_.RE'),
#  ('h1810095@nushigh.edu.sg', '22.089.YLL_.BI'),
#  ('h1810096@nushigh.edu.sg', '22.089.YLL_.BI'),
#  ('h1810117@nushigh.edu.sg', '22.089.YLL_.BI'),
#  ('h1810052@nushigh.edu.sg', '22.090.SRIS.BI'),
#  ('h1810069@nushigh.edu.sg', '22.090.SRIS.BI'),
#  ('h1810109@nushigh.edu.sg', '22.091.NUSB.BI'),
#  ('h1810128@nushigh.edu.sg', '22.091.NUSB.BI'),
#  ('h2030001@nushigh.edu.sg', '22.091.NUSB.BI'),
#  ('h1810098@nushigh.edu.sg', '22.092.NUSH.MA'),
#  ('h1810160@nushigh.edu.sg', '22.092.NUSH.MA'),
#  ('h2030003@nushigh.edu.sg', '22.092.NUSH.MA'),
#  ('h1810125@nushigh.edu.sg', '22.095.NUSE.CS'),
#  ('h1910059@nushigh.edu.sg', '22.095.NUSE.CS'),
#  ('h1810071@nushigh.edu.sg', '22.096.NUH_.BI'),
#  ('h1810156@nushigh.edu.sg', '22.096.NUH_.BI'),
#  ('h1810158@nushigh.edu.sg', '22.096.NUH_.BI'),
#  ('h1810011@nushigh.edu.sg', '22.097.YLL_.BI'),
#  ('h1810112@nushigh.edu.sg', '22.097.YLL_.BI'),
#  ('h1810127@nushigh.edu.sg', '22.097.YLL_.BI'),
#  ('h1810149@nushigh.edu.sg', '22.099.NUSC.CM'),
#  ('h1810143@nushigh.edu.sg', '22.100.NTU_.RE'),
#  ('h1810099@nushigh.edu.sg', '22.101.IMRE.PH'),
#  ('h1810101@nushigh.edu.sg', '22.102.SUTD.RE'),
#  ('h1810010@nushigh.edu.sg', '22.103.NUSB.BI'),
#  ('h1810083@nushigh.edu.sg', '22.103.NUSB.BI'),
#  ('h1810119@nushigh.edu.sg', '22.103.NUSB.BI'),
#  ('h1810026@nushigh.edu.sg', '22.104.IHPC.RE'),
#  ('h1810089@nushigh.edu.sg', '22.104.IHPC.RE'),
#  ('h1810121@nushigh.edu.sg', '22.104.IHPC.RE'),
#  ('h1910013@nushigh.edu.sg', '22.105.DSO_.PH'),
#  ('h1810061@nushigh.edu.sg', '22.106.YLL_.BI'),
#  ('h1810102@nushigh.edu.sg', '22.106.YLL_.BI'),
#  ('h1810123@nushigh.edu.sg', '22.106.YLL_.BI'),
#  ('h1810086@nushigh.edu.sg', '22.107.NUSG.CS'),
#  ('h1810024@nushigh.edu.sg', '22.109.NUSC.CM'),
#  ('h1810045@nushigh.edu.sg', '22.109.NUSC.CM'),
#  ('h1810078@nushigh.edu.sg', '22.109.NUSC.CM'),
#  ('h1910092@nushigh.edu.sg', '22.111.NUSH.MA'),
#  ('h1910111@nushigh.edu.sg', '22.111.NUSH.MA'),
#  ('h1910144@nushigh.edu.sg', '22.111.NUSH.MA'),
#  ('h1910064@nushigh.edu.sg', '22.112.NUSH.MA'),
#  ('h1910077@nushigh.edu.sg', '22.112.NUSH.MA'),
#  ('h1910110@nushigh.edu.sg', '22.112.NUSH.MA'),
#  ('h1910140@nushigh.edu.sg', '22.113.NUSH.MA'),
#  ('h2130007@nushigh.edu.sg', '22.113.NUSH.MA'),
#  ('h2010018@nushigh.edu.sg', '22.114.NUSH.MA'),
#  ('h2010103@nushigh.edu.sg', '22.114.NUSH.MA'),
#  ('h2010104@nushigh.edu.sg', '22.114.NUSH.MA'),
#  ('h1910027@nushigh.edu.sg', '22.115.NUSH.MA'),
#  ('h1910155@nushigh.edu.sg', '22.115.NUSH.MA'),
#  ('h1910020@nushigh.edu.sg', '22.116.NUSH.MA'),
#  ('h1910075@nushigh.edu.sg', '22.116.NUSH.MA'),
#  ('h1810059@nushigh.edu.sg', '22.118.NUSH.MA'),
#  ('h1810136@nushigh.edu.sg', '22.118.NUSH.MA'),
#  ('h1810157@nushigh.edu.sg', '22.118.NUSH.MA'),
#  ('h2010067@nushigh.edu.sg', '22.119.NUSH.MA'),
#  ('h2010098@nushigh.edu.sg', '22.119.NUSH.MA'),
#  ('h1910013@nushigh.edu.sg', '22.120.NERI.BI'),
#  ('h1910051@nushigh.edu.sg', '22.120.NERI.BI'),
#  ('h1910095@nushigh.edu.sg', '22.120.NERI.BI'),
#  ('h1910021@nushigh.edu.sg', '22.122.NUSC.CM'),
#  ('h1910162@nushigh.edu.sg', '22.122.NUSC.CM'),
#  ('h2130009@nushigh.edu.sg', '22.122.NUSC.CM'),
#  ('h1810076@nushigh.edu.sg', '22.123.BII_.CM'),
#  ('h1810085@nushigh.edu.sg', '22.123.BII_.CM'),
#  ('h1810157@nushigh.edu.sg', '22.123.BII_.CM'),
#  ('h1810032@nushigh.edu.sg', '22.124.NTU_.PH'),
#  ('h1810054@nushigh.edu.sg', '22.124.NTU_.PH'),
#  ('h1810070@nushigh.edu.sg', '22.124.NTU_.PH'),
#  ('h1810161@nushigh.edu.sg', '22.125.NUSE.CM'),
#  ('h2030006@nushigh.edu.sg', '22.125.NUSE.CM'),
#  ('h1810009@nushigh.edu.sg', '22.126.NUSH.MA'),
#  ('h1810039@nushigh.edu.sg', '22.126.NUSH.MA'),
#  ('h1810056@nushigh.edu.sg', '22.127.NUSB.BI'),
#  ('h1810062@nushigh.edu.sg', '22.127.NUSB.BI'),
#  ('h1810025@nushigh.edu.sg', '22.129.NUSA.CM'),
#  ('h1810077@nushigh.edu.sg', '22.129.NUSA.CM'),
#  ('h1810049@nushigh.edu.sg', '22.131.IMRE.CM'),
#  ('h2030010@nushigh.edu.sg', '22.132.NUSH.MA'),
#  ('h1810021@nushigh.edu.sg', '22.133.NUSB.BI'),
#  ('h1810063@nushigh.edu.sg', '22.133.NUSB.BI'),
#  ('h1810131@nushigh.edu.sg', '22.133.NUSB.BI'),
#  ('h1810133@nushigh.edu.sg', '22.134.LKCS.BI'),
#  ('h1810134@nushigh.edu.sg', '22.134.LKCS.BI'),
#  ('h1810135@nushigh.edu.sg', '22.134.LKCS.BI'),
#  ('h1810120@nushigh.edu.sg', '22.135.IHPC.BI'),
#  ('h1810126@nushigh.edu.sg', '22.137.DIGI.CS'),
#  ('h1810146@nushigh.edu.sg', '22.137.DIGI.CS'),
#  ('h1810166@nushigh.edu.sg', '22.137.DIGI.CS'),
#  ('h1710080@nushigh.edu.sg', '22.138.NUSP.PH'),
#  ('h1810113@nushigh.edu.sg', '22.138.NUSP.PH'),
#  ('h1810152@nushigh.edu.sg', '22.138.NUSP.PH'),
#  ('h1810001@nushigh.edu.sg', '22.139.NUSP.PH'),
#  ('h1810051@nushigh.edu.sg', '22.139.NUSP.PH'),
#  ('h1810148@nushigh.edu.sg', '22.139.NUSP.PH'),
#  ('h1910004@nushigh.edu.sg', '22.140.NUSC.CM'),
#  ('h1910086@nushigh.edu.sg', '22.140.NUSC.CM'),
#  ('h1910102@nushigh.edu.sg', '22.140.NUSC.CM'),
#  ('h1810068@nushigh.edu.sg', '22.141.NUSH.CS'),
#  ('h1810153@nushigh.edu.sg', '22.141.NUSH.CS'),
#  ('h2030012@nushigh.edu.sg', '22.141.NUSH.CS'),
#  ('h1810081@nushigh.edu.sg', '22.142.NUSH.CS'),
#  ('h1910001@nushigh.edu.sg', '22.143.NUSH.CM'),
#  ('h1910117@nushigh.edu.sg', '22.143.NUSH.CM'),
#  ('h1810162@nushigh.edu.sg', '22.144.NUSB.RE'),
#  ('h1810087@nushigh.edu.sg', '22.147.NUSC.CM'),
#  ('h1810147@nushigh.edu.sg', '22.147.NUSC.CM'),
#  ('h1910048@nushigh.edu.sg', '22.149.NUSC.CM'),
#  ('h1910098@nushigh.edu.sg', '22.149.NUSC.CM'),
#  ('h1910108@nushigh.edu.sg', '22.149.NUSC.CM'),
#  ('h1910046@nushigh.edu.sg', '22.151.NUSH.MA'),
#  ('h1910048@nushigh.edu.sg', '22.151.NUSH.MA'),
#  ('h1910059@nushigh.edu.sg', '22.151.NUSH.MA'),
#  ('h1810023@nushigh.edu.sg', '22.152.NUSH.MA'),
#  ('h2010154@nushigh.edu.sg', '22.154.NUSH.MA'),
#  ('h1810167@nushigh.edu.sg', '22.155.IMCB.BI'),
#  ('h1810046@nushigh.edu.sg', '22.156.NUSH.RE'),
#  ('h1810085@nushigh.edu.sg', '22.156.NUSH.RE'),
#  ('h1810170@nushigh.edu.sg', '22.156.NUSH.RE'),
#  ('h1810122@nushigh.edu.sg', '22.157.NUSH.BI'),
#  ('h1810152@nushigh.edu.sg', '23.001.NUSH.MA'),
#  ('h1810154@nushigh.edu.sg', '23.001.NUSH.MA'),
#  ('h2010009@nushigh.edu.sg', '23.002.NUSH.BI'),
#  ('h2010118@nushigh.edu.sg', '23.002.NUSH.BI'),
#  ('h2010120@nushigh.edu.sg', '23.002.NUSH.BI'),
#  ('h2010055@nushigh.edu.sg', '23.003.NUSH.BI'),
#  ('h2010169@nushigh.edu.sg', '23.003.NUSH.BI'),
#  ('h1810079@nushigh.edu.sg', '23.006.NSPC.PH'),
#  ('h1810116@nushigh.edu.sg', '23.006.NSPC.PH'),
#  ('h1810142@nushigh.edu.sg', '23.006.NSPC.PH'),
#  ('h1810084@nushigh.edu.sg', '23.007.NUSH.CS'),
#  ('h1810125@nushigh.edu.sg', '23.007.NUSH.CS'),
#  ('h1910133@nushigh.edu.sg', '23.009.TLL_.BI'),
#  ('ashwin_lokesh@students.edu.sg', '23.010.SIT_.CS'),
#  ('h1810086@nushigh.edu.sg', '23.010.SIT_.CS'),
#  ('h1810124@nushigh.edu.sg', '23.010.SIT_.CS'),
#  ('ishneet_singh@temasekjc.moe.edu.sg', '23.010.SIT_.CS'),
#  ('lam.yikting@dhs.edu.sg', '23.010.SIT_.CS'),
#  ('yau_le_qi@temasekjc.moe.edu.sg', '23.010.SIT_.CS'),
#  ('h1810065@nushigh.edu.sg', '23.011.SGH_.CS'),
#  ('h1910133@nushigh.edu.sg', '23.012.NUSB.BI'),
#  ('h2130003@nushigh.edu.sg', '23.012.NUSB.BI'),
#  ('h1910013@nushigh.edu.sg', '23.013.NUSH.PH'),
#  ('h1910144@nushigh.edu.sg', '23.013.NUSH.PH'),
#  ('h1910164@nushigh.edu.sg', '23.013.NUSH.PH'),
#  ('h1910088@nushigh.edu.sg', '23.015.NUSB.BI'),
#  ('h1910142@nushigh.edu.sg', '23.015.NUSB.BI'),
#  ('h2010154@nushigh.edu.sg', '23.016.NUSH.MA'),
#  ('h1910157@nushigh.edu.sg', '23.017.NUSH.PH'),
#  ('h1810111@nushigh.edu.sg', '23.018.NUSH.CS'),
#  ('h1810124@nushigh.edu.sg', '23.018.NUSH.CS'),
#  ('h1810167@nushigh.edu.sg', '23.018.NUSH.CS'),
#  ('h1810084@nushigh.edu.sg', '23.019.NUSH.PH'),
#  ('h1810084@nushigh.edu.sg', '23.020.NUSH.PH'),
#  ('h1810125@nushigh.edu.sg', '23.020.NUSH.PH'),
#  ('h1810084@nushigh.edu.sg', '23.021.NUSH.PH'),
#  ('h1810125@nushigh.edu.sg', '23.021.NUSH.PH'),
#  ('h1910059@nushigh.edu.sg', '23.021.NUSH.PH'),
#  ('h1810074@nushigh.edu.sg', '23.029.NUSH.RE'),
#  ('h1810097@nushigh.edu.sg', '23.029.NUSH.RE'),
#  ('h1810168@nushigh.edu.sg', '23.029.NUSH.RE'),
#  ('h1810038@nushigh.edu.sg', '23.030.NUSH.PH'),
#  ('h1810124@nushigh.edu.sg', '23.030.NUSH.PH'),
#  ('h1810159@nushigh.edu.sg', '23.030.NUSH.PH'),
#  ('h1810166@nushigh.edu.sg', '23.030.NUSH.PH'),
#  ('h1810035@nushigh.edu.sg', '23.031.IMCB.RE'),
#  ('h1810114@nushigh.edu.sg', '23.031.IMCB.RE'),
#  ('h1810048@nushigh.edu.sg', '23.032.NUSH.HU'),
#  ('h1810106@nushigh.edu.sg', '23.032.NUSH.HU'),
#  ('h1810164@nushigh.edu.sg', '23.032.NUSH.HU'),
#  ('h1810140@nushigh.edu.sg', '23.033.NUSH.HU'),
#  ('h1810105@nushigh.edu.sg', '23.036.IBB_.BI'),
#  ('h1710054@nushigh.edu.sg', '23.038.NUSH.PH')]

# %%
# %%sql
# SELECT * FROM ProjectContinuation
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 2 rows affected.
# [('22.011.NUSH.PH', '23.030.NUSH.PH'), ('20.022.NUSE.PH', '23.018.NUSH.CS')]

# %%
# %%sql
# SELECT * FROM Mentors
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 12 rows affected.
# [('zning@nuspace.sg', '21.048.NSPC.PH'),
#  ('zning@nuspace.sg', '21.050.NSPC.PH'),
#  ('zning@nuspace.sg', '23.013.NUSH.PH'),
#  ('zning@nuspace.sg', '23.006.NSPC.PH'),
#  ('rishabh_bhardwaj@mymail.sutd.edu.sg', '22.079.SUTD.CS'),
#  ('truonghuu.tram@singaporetech.edu.sg', '23.010.SIT_.CS'),
#  ('immanuel_koh@sutd.edu.sg', '21.029.SUTD.CS'),
#  ('arthurtay@nus.edu.sg', '20.022.NUSE.PH'),
#  ('huangshaoying@sutd.edu.sg', '22.077.SUTD.PH'),
#  ('elie.hosry@singaporetech.edu.sg', '22.137.DIGI.CS'),
#  ('hklim@smu.edu.sg', '22.041.SMU_.MA'),
#  ('hoinok.tsao@nie.edu.sg', '22.066.NIE_.PH')]

# %%
# %%sql
# SELECT * FROM Organises
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 12 rows affected.
# [('STYau', 2022, 'ASHK'),
#  ('SSEF', 2021, 'ASTAR'),
#  ('SSEF', 2022, 'ASTAR'),
#  ('SSEF', 2023, 'ASTAR'),
#  ('isyfDigital', 2021, 'HCI'),
#  ('isyfDigital', 2022, 'HCI'),
#  ('GYSTB', 2021, 'HKFYG'),
#  ('Globecom', 2023, 'IEEE'),
#  ('IRC-SET', 2021, 'IRC'),
#  ('SSEF', 2021, 'SCS'),
#  ('SSEF', 2022, 'SCS'),
#  ('SSEF', 2023, 'SCS')]

# %%
# %%sql
# SELECT * FROM AwardTypes
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 65 rows affected.
# [('GYSTB', 2021, 'Bronze Award'),
#  ('GYSTB', 2021, 'First Prize'),
#  ('GYSTB', 2021, 'Fourth Prize'),
#  ('GYSTB', 2021, 'Gold Award'),
#  ('GYSTB', 2021, 'Second Prize'),
#  ('GYSTB', 2021, 'Silver Award'),
#  ('GYSTB', 2021, 'Third Prize'),
#  ('IRC-SET', 2021, 'Best Paper Award'),
#  ('IRC-SET', 2021, 'Best Presenter Award'),
#  ('isyfDigital', 2021, '1st Place'),
#  ('isyfDigital', 2021, '2nd Place'),
#  ('isyfDigital', 2021, '3rd Place'),
#  ('SSEF', 2021, 'Bronze'),
#  ('SSEF', 2021, 'ECS Special Award'),
#  ('SSEF', 2021, 'Gold'),
#  ('SSEF', 2021, 'IChemE Award'),
#  ('SSEF', 2021, 'Merit'),
#  ('SSEF', 2021, 'SAAS Poster Award'),
#  ('SSEF', 2021, 'Silver'),
#  ('SSEF', 2021, 'SMS Award for Ingenuity'),
#  ('SSEF', 2021, 'SSMB Award'),
#  ('SSEF', 2021, 'SUTD R&I Award: Artificial Intelligence'),
#  ('SSEF', 2021, 'SUTD R&I Award: Aviation'),
#  ('SSEF', 2021, 'SUTD R&I Award: Cities'),
#  ('SSEF', 2021, 'SUTD R&I Award: Healthcare'),
#  ('SSEF', 2021, 'SUTD R&I Award: Multi-Disciplinary'),
#  ('SSEF', 2021, 'Yale-NUS Special Award'),
#  ('SSEF', 2022, 'Bronze'),
#  ('SSEF', 2022, 'ECS Special Award'),
#  ('SSEF', 2022, 'Gold'),
#  ('SSEF', 2022, 'IChemE Award'),
#  ('SSEF', 2022, 'Merit'),
#  ('SSEF', 2022, 'SAAS Poster Award'),
#  ('SSEF', 2022, 'Silver'),
#  ('SSEF', 2022, 'SMS Award for Ingenuity'),
#  ('SSEF', 2022, 'SSMB Award'),
#  ('SSEF', 2022, 'SUTD R&I Award: Artificial Intelligence'),
#  ('SSEF', 2022, 'SUTD R&I Award: Aviation'),
#  ('SSEF', 2022, 'SUTD R&I Award: Cities'),
#  ('SSEF', 2022, 'SUTD R&I Award: Healthcare'),
#  ('SSEF', 2022, 'SUTD R&I Award: Multi-Disciplinary'),
#  ('SSEF', 2022, 'Yale-NUS Special Award'),
#  ('SSEF', 2023, 'Bronze'),
#  ('SSEF', 2023, 'ECS Special Award'),
#  ('SSEF', 2023, 'Gold'),
#  ('SSEF', 2023, 'IChemE Award'),
#  ('SSEF', 2023, 'Merit'),
#  ('SSEF', 2023, 'SAAS Poster Award'),
#  ('SSEF', 2023, 'Silver'),
#  ('SSEF', 2023, 'SMS Award for Ingenuity'),
#  ('SSEF', 2023, 'SSMB Award'),
#  ('SSEF', 2023, 'SUTD R&I Award: Artificial Intelligence'),
#  ('SSEF', 2023, 'SUTD R&I Award: Aviation'),
#  ('SSEF', 2023, 'SUTD R&I Award: Cities'),
#  ('SSEF', 2023, 'SUTD R&I Award: Healthcare'),
#  ('SSEF', 2023, 'SUTD R&I Award: Multi-Disciplinary'),
#  ('SSEF', 2023, 'Yale-NUS Special Award'),
#  ('STYau', 2022, 'Charles K. Kao High School Physics Gold Award'),
#  ('STYau', 2022, 'Chin-Yin Chiu High School Economic and Financial Modeling Gold Award'),
#  ('STYau', 2022, 'Ching W. Tang High School Chemistry Gold Award'),
#  ('STYau', 2022, 'Harry Shum High School Computer Science Gold Award'),
#  ('STYau', 2022, 'Honorable Mention'),
#  ('STYau', 2022, 'Shiing-Shen Chern High School Mathematics Gold Award'),
#  ('STYau', 2022, 'Silver Prize'),
#  ('STYau', 2022, 'Yuet-Wai Kan High School Biology Gold Award')]

# %%
# %%sql
# SELECT * FROM Submission
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 99 rows affected.
# [('Globecom', 2023, '23.010.SIT_.CS', 'A Novel Feature Vector for Windows Malware Detection using Deep Learning', 'Dynamic malware analysis, which has been a major field in malware analysis and detection, involves executing the malware in a controlled environment  ... (1079 characters truncated) ... rmance metrics such as accuracy, and false positive or false negative rate, thus proving the effectiveness of our feature vector and detection model.'),
#  ('GYSTB', 2021, 'IBPE07', "Gait Monitoring and Analysis for Parkinson's Disease Patients", 'Parkinson’s disease (PD) is a neurodegenerative disorder that affects the dopamine producing neurons in the substantia nigra, an area of the brain, l ... (942 characters truncated) ... rate at predicting FoG. Ultimately, a small and lightweight prototype was created based on acceleration data from accelerometers placed on the thigh.'),
#  ('IRC-SET', 2021, 'P23', "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms", 'Parkinson’s disease (PD) is a neurodegenerative disorder that affects the dopamine producing neurons in the substantia nigra, an area of the brain, l ... (942 characters truncated) ... rate at predicting FoG. Ultimately, a small and lightweight prototype was created based on acceleration data from accelerometers placed on the thigh.'),
#  ('ISYFdigital', 2021, '20.022.NUSE.PH', "Gait Monitoring and Analysis for Parkinson's Disease Patients", 'Parkinson’s disease (PD) is a neurodegenerative disorder that affects the dopamine producing neurons in the substantia nigra, an area of the brain, l ... (942 characters truncated) ... rate at predicting FoG. Ultimately, a small and lightweight prototype was created based on acceleration data from accelerometers placed on the thigh.'),
#  ('SSEF', 2021, 'BE018', "Gait Monitoring and Analysis for Parkinson's Disease Patients", 'Parkinson’s disease (PD) is a neurodegenerative disorder that affects the dopamine producing neurons in the substantia nigra, an area of the brain, l ... (942 characters truncated) ... rate at predicting FoG. Ultimately, a small and lightweight prototype was created based on acceleration data from accelerometers placed on the thigh.'),
#  ('SSEF', 2022, 'PH008', 'An Investigation on the aerodynamics of flight of a hand helicopter', 'A simple hand helicopter can be made by attaching rotor blades to one end of a vertical stick. The helicopter moves upwards when the stick is spun ab ... (718 characters truncated) ... al maximum height. The conditions required for the hand helicopter to fly stably are also investigated and explained using the Tennis Racket Theorem.'),
#  ('SSEF', 2022, 'RO014', 'Embodied AI for computational perception and understanding of spatial designs', 'Semantic Segmentation is a computer vision task used to identify specific regions of interest for virtual agents and autonomous robots or vehicles, s ... (754 characters truncated) ... ound that transfer learning with semantic segmentation is an effective way to comprehend the design and layouts of these HDB interiors and exteriors.'),
#  ('SSEF', 2023, 'AS004', 'Ecological Footprint of Smallholder vs Industrial Oil Palm Plantations in Indonesia', ''),
#  ('SSEF', 2023, 'AS007', 'Reliability of coral species identification for traceability in the aquarium trade', ''),
#  ('SSEF', 2023, 'AS008', 'Human Disturbances and its Effects on Bird Diversity in Lakeside Garden', ''),
#  ('SSEF', 2023, 'AS009', 'Active matter cytometry for high-resolution sizing, sorting of zebrafish larvae', 'In aquaculture farming, uneven larval growth is often observed and sorting at the early stages is necessary to prevent cannibalism and uneven product ... (1128 characters truncated) ... sing component, we can also utilize our design for high-quality imaging of larvae and make use of machine learning for other classification criteria.'),
#  ('SSEF', 2023, 'BE018', 'Shielding-Free Signal Noise Suppression in Portable Low-Field MRI', 'Portable Magnetic Resonance Imaging (poMRI) setups allow for point-of-care imaging, which can greatly enrich paramedic services. However, these setup ... (739 characters truncated) ... wing for on-the-spot calibration. Our noise suppression method might significantly improve the image quality of poMRI, without the need for a shield.'),
#  ('SSEF', 2023, 'BE022', 'Low Dose, High Accuracy: Using Deep Learning to Enhance 3D Tomography', 'Computed tomography is a imaging technique that makes use of particles such as x-ray photons to examine the interiors of objects. It has become an in ... (994 characters truncated) ... sages, with our model achieving a peak-signal-to-noise-ratio of 32.24 and structural similarity index of 0.781 even when 90% of sinograms are masked.'),
#  ('SSEF', 2023, 'BE023', "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms", 'Parkinson’s Disease (PD) is a neurodegenerative disease that affects the substantia nigra, a region in the brain. It causes many hindrances to activi ... (1031 characters truncated) ... ck freeze events over a period of time. This can help doctors diagnose patients and gauge the severity of the disease, so as to prescribe medication.'),
#  ('SSEF', 2023, 'BE024', 'Qualitative Cardioscopic Analysis of Tricuspid Valve Apparatus in a Semi-Pulsatile Fluid Dynamic Model', ''),
#  ('SSEF', 2023, 'BE026', 'In Vitro Hemodynamic Assessment Model for Implantable Tricuspid Valve in a 3D Printed Human Heart with Fluid Dynamic Physiology in Cardio-pulmonary Bypass State', ''),
#  ('SSEF', 2023, 'BH009', 'Effect of different genres of music on food perception ', ''),
#  ('SSEF', 2023, 'BH017', 'Neurocognitive Functioning and School Performance in Students With Special Educational Needs', ''),
#  ('SSEF', 2023, 'BH021', 'Young people’s preferences in movies: Evaluating the effectivess of movie ratings', ''),
#  ('SSEF', 2023, 'BH025', 'Investigating the effect of colours on Medical Facilities', ''),
#  ('SSEF', 2023, 'BI007', 'Sensitisation Profiles of House Dust Mite-allergic Subjects using an Allergen Microarray Platform', ''),
#  ('SSEF', 2023, 'BM001', 'Investigating sputum CD62L levels in clinical asthma of varying severity', ''),
#  ('SSEF', 2023, 'BM018', 'Prevalence of Allergies in Singaporean Teens', ''),
#  ('SSEF', 2023, 'BM019', 'Investigating the association of antenatal mosquito-borne viral infections on pregnancy and child outcomes in Singapore', ''),
#  ('SSEF', 2023, 'BM021', 'Tuning T-lymphocytes to improve wound healing', ''),
#  ('SSEF', 2023, 'BM024', 'A Retrospective Colectomy Study on Post-operative Drain Use & Complications', ''),
#  ('SSEF', 2023, 'CB016', 'Enhanced antibacterial activity of a novel phage-antibiotic combination against Klebsiella pneumoniae isolates', 'Klebsiella pneumoniae is a highly prevalent, multi-drug resistant pathogen which is associated with high morbidity and mortality rates due to the lim ... (1280 characters truncated) ... of our novel phage-antibiotic cocktail in treating K. pneumoniae infections in patients who do not respond to conventional antibiotic\xa0therapy.\xa0'),
#  ('SSEF', 2023, 'CB017', 'The effect of fluidizers on the structure and dynamics of live cell membranes studied by single molecule fluorescence microscopy', ''),
#  ('SSEF', 2023, 'CB018', 'Optimization of logic gates for one-step detection of microRNAs via Split loop-mediated isothermal amplification (Split-LAMP)', ''),
#  ('SSEF', 2023, 'CB021', 'Investigating the Gal-3 rs4644 Single Nucleotide Polymorphisms effects on CaV-1.2 Calcium Channels in Hypertension ', ''),
#  ('SSEF', 2023, 'CB022', 'Developing an Optogenetic O-GlcNAc Transferase for Single Protein O-GlcNAcylation in Cells', ''),
#  ('SSEF', 2023, 'CH005', 'Interactions between polyethylene and emerging organic contaminants, and its applications: adsorption in different mediums and effect of aging', ''),
#  ('SSEF', 2023, 'CH027', 'Characterisation and correlations of free fatty acid compositions of cooking oils with Heme-mediated lipid peroxidation reactions', ''),
#  ('SSEF', 2023, 'CH028', 'Paper-based chemical sensors for food freshness monitoring', ''),
#  ('SSEF', 2023, 'CH029', 'Synthesis of mixed ligand MIL-53(Al) for defect engineering', ''),
#  ('SSEF', 2023, 'CH032', 'First principles investigation of electronic structure, ligand field and magnetism of Re(III) compounds', ''),
#  ('SSEF', 2023, 'CH034', 'Purifying Nanoplastic-Contaminated Water with Functionalised Cellulose Extracted from Lychee Peels', ''),
#  ('SSEF', 2023, 'CH035', 'Enantioselective synthesis of biaryl atropisomers from Suzuki-Miyaura reaction using ionic interactions', ''),
#  ('SSEF', 2023, 'CO001', 'Deep Learning Model for the Prediction of Antimicrobial Agents', "In the face of increasing antimicrobial resistance, antimicrobial peptides (AMPs) have shown great potential as an alternative method to kill or inhi ... (793 characters truncated) ... rain at or above 70\\% confidence level. In future work, we hope to do wet-lab testing to determine the actual efficacy of the suggested\xa0peptides."),
#  ('SSEF', 2023, 'CO021', 'A Computational Approach to Modelling Medieval Royal Families', ''),
#  ('SSEF', 2023, 'EA007', 'Potential Factors influencing Local Butterfly Biodiversity in Park Connectors', ''),
#  ('SSEF', 2023, 'EA009', 'Novel Primary Data Collection and Classification of Microplastics in Coastal Waters of Singapore for Research Usage', ''),
#  ('SSEF', 2023, 'EA014', 'Analysing Environmental Influences on the Plant Diversity of a Naturalised Plot', ''),
#  ('SSEF', 2023, 'EA016', 'Quantification of Microplastics Bioaccumulation in Clam Using the Benchtop MALDI-TOF', ''),
#  ('SSEF', 2023, 'EE002', 'Application of water hyacinth as a low-cost biosorbent for dyes in textile wastewater', ''),
#  ('SSEF', 2023, 'EE018', 'Investigating The Effects Of Microbiological Co-processing Of Food And Yard Waste To Modify Bioreactor\xa0Designs', ''),
#  ('SSEF', 2023, 'EE020', 'Performance Evaluation of Recycled Acyl-Modified Chitosan Filtration Membranes on Polluted Water Using Spectroscopic Techniques', 'Annual global crustacean shell waste amounts to 6-8 million tonnes, with 1.5 million in Southeast Asia. A novel method for designing membrane filters ... (1458 characters truncated) ... tes the potential of custom-modified chitosan membranes manufactured from eco-friendly sources as highly selective filters for water\xa0purification.'),
#  ('SSEF', 2023, 'EE029', 'Construction of a Low-Energy Capacitive Deionisation Device for Effective Desalination', ''),
#  ('SSEF', 2023, 'EE030', 'Self Healing of Concrete with Recycled Concrete Aggregates', ''),
#  ('SSEF', 2023, 'EE039', 'Pleurotus Ostreatus growth in Barley-cardboard substrate in soil', ''),
#  ('SSEF', 2023, 'ES005', 'The bird in the swarm: how to detect and resolve closely-spaced targets in radar', ''),
#  ('SSEF', 2023, 'ES008', 'Image Capture System for a Nanosatellite', ''),
#  ('SSEF', 2023, 'ES009', 'Optimization of the Telemetry, Tracking and Commmunications System in a CubeSat', 'The growing commercialisation of the space industry and novel developments in miniaturisation technology has led to an increase of adoption of Cube-S ... (604 characters truncated) ... ground station. Further bit-encoding and error correction is performed, resulting in a robust, efficient and simple means of Satellite image capture.'),
#  ('SSEF', 2023, 'ET009', 'Optimisation of the Design of an Electromagnetic Projectile Launcher', ''),
#  ('SSEF', 2023, 'ET018', 'Implementation of an Electrical Power System on a 1U CubeSat', ''),
#  ('SSEF', 2023, 'EY003', 'Development of photoluminescence imaging for perovskite solar cells', ''),
#  ('SSEF', 2023, 'EY007', 'Optically and Wirelessly Re-chargeable Buffer Batteries', 'Photocapacitors are a type of capacitors that can be wirelessly charged through exposure to electromagnetic radiation. This combines the functions of ... (1136 characters truncated) ... works. Sensitivity to infrared radiation allows usage in places impenetrable by visible light such as in internal organs and interior of electronics.'),
#  ('SSEF', 2023, 'EY010', 'Solid State Materials for Energy Harvesting and Cooling: from Materials Synthesis, Characterization, and Analysis to Applications', ''),
#  ('SSEF', 2023, 'HB014', 'Cultural adaptation of the dietary choice of international students living in boarding schools', ''),
#  ('SSEF', 2023, 'MA001', 'On the Application of Inequalities Containing Sums of Minimum/Maximum of Numbers', ''),
#  ('SSEF', 2023, 'MA013', 'Exploring the maximum volume and surface area of polyhedra inscribed in a sphere', ''),
#  ('SSEF', 2023, 'MA017', 'Representing Royal Families using Graph Theory', 'Historians studying mediaeval royal families have faced challenges understanding the chaotic dynamics of the family trees. This has made research in  ... (1238 characters truncated) ... ld form the foundation for future more complex and flexible formulas, and thus is a step closer to describing what seemed to be a chaotic phenomenon.'),
#  ('SSEF', 2023, 'MA018', 'On the Modification of Recursive Sequences of the form an = an-1 + an-j', ''),
#  ('SSEF', 2023, 'MA019', 'Dungeons and Dragons Inspired Cantrip Knockout Prediction: Error-mimimising Numerical Investigative Study', ''),
#  ('SSEF', 2023, 'MA021', 'Chromatic Number of Graph Powers', ''),
#  ('SSEF', 2023, 'MA023', 'Exploring the Maximum Area of Triangles Inscribed in Various Conic Sections', ''),
#  ('SSEF', 2023, 'MA030', 'Approaching Hadwiger’s Conjecture using List Coloring', ''),
#  ('SSEF', 2023, 'MI001', 'Optimising in vitro production of late stage Plasmodium falciparum gametocytes for Anopheles sinensis infection', ''),
#  ('SSEF', 2023, 'MI006', 'Investigating the Prevalence and Antibiotic Resistance of Klebsiella pneumoniae in Surface Water: An Antibiotic Resistance Profiling and Risk Assessment\xa0Study', ''),
#  ('SSEF', 2023, 'MI009', 'Nonlesional skin microbiome differs between children with atopic dermatitis (AD) and those with history of AD', ''),
#  ('SSEF', 2023, 'MS001', 'Exploring the Electrical Characteristics of 2D Semiconductors for Quantum Computing', ''),
#  ('SSEF', 2023, 'MS004', 'Synthesis of Peptide Nanomaterials via Controlled Self-Assembly', ''),
#  ('SSEF', 2023, 'MS020', 'Power Supply System for Smart Contact Lens', ''),
#  ('SSEF', 2023, 'MS025', 'Growth and Crystallographic Characterisation of Beryllium Nitride Crystals as a Novel Semiconductor Material', ''),
#  ('SSEF', 2023, 'MS031', 'The Effect of Different Storage Conditions on Fruit Peels for the Green Synthesis of Silver Nanoparticles', ''),
#  ('SSEF', 2023, 'MS033', 'Laser-Transformed C-ZnTi as Luminous Photosensor', ''),
#  ('SSEF', 2023, 'MS037', 'Using FTIR to investigate plastic degradation by white rot fungi ', ''),
#  ('SSEF', 2023, 'MS041', 'Investigating the effects of hydrophilicity and heat on the exfoliation of WS2', ''),
#  ('SSEF', 2023, 'PH015', 'Reflectarray design based on rectangular pheonix cell', ''),
#  ('SSEF', 2023, 'PH017', 'Infrared Laser Locking to Rubidium Saturated Absorption Spectrum', ''),
#  ('SSEF', 2023, 'PH022', 'An Automated Screening System for Trinary Star System Candidates', 'The discovery and cataloguing of trinary star systems is of significant interest to the field of astronomy, with implications from stellar system for ... (847 characters truncated) ... ation of trinary stars. Our classification of the dataset, alongside all source code, is available at https://github.com/three-body-analysis/codebase'),
#  ('SSEF', 2023, 'PH023', 'On the Vibroacoustic Modelling of Tensioned Elastic Membranes in a Pressurised Air Cavity', ''),
#  ('SSEF', 2023, 'PH025', 'Interactions between Vortex Rings and Solid Boundaries', ''),
#  ('SSEF', 2023, 'PH029', 'Numerical Methods for Computation of Particles in Fusion Hot Spots', ''),
#  ('SSEF', 2023, 'PS009', 'Heterologous Expression of Avicennia Officinalis Cation-Chloride Cotransporter (CCC1) In Arabidopsis and Yeast and It’s Role in the Regulation Of Salt Tolerance', ''),
#  ('SSEF', 2023, 'PS022', 'Understanding the Genetic Basis of Resistance to Combined Heat and Drought stress in Arabidopsis thaliana accessions response to heat and drought stress', ''),
#  ('SSEF', 2023, 'PS049', 'How do composts made from banana peels, apple peels and orange peels affect the growth of a plant?', ''),
#  ('SSEF', 2023, 'RO028', 'Deep Equilibrium BERT', 'Deep Equilibrium Models (DEQ) are a class of implicit neural networks that have recently gained attention due to their competitive performance agains ... (699 characters truncated) ... odel encourages further exploration and improvement of DEQ language models. All source code can be found at github.com/Clyde013/DeepEquilibrium-BERT.'),
#  ('SSEF', 2023, 'RO030', 'Explainable Video Analytics - A wide area multi-camera tracking perspective', ''),
#  ('SSEF', 2023, 'RO032', 'Longest simple path with Machine Learning', 'The longest simple path problem on general undirected graphs is a well-studied NP-Complete problem. It has applications in circuit board design, robo ... (631 characters truncated) ...  on our testing dataset and the graph neural network was able to perform better than some of the best algorithms that were done\xa0in\xa0the\xa0past.'),
#  ('SSEF', 2023, 'RO040', 'Multimodal assessment and coaching feedback to improve Public Speaking performance', ''),
#  ('SSEF', 2023, 'RO041', 'Deep learning model for the diagnosis of exudative pharyngitis', 'Background: Telemedicine is firmly established in the healthcare landscape of many countries. Acute respiratory infection is the most common reason f ... (1384 characters truncated) ... learning for the diagnosis of exudative pharyngitis. I have deployed the model on a web application for automated diagnosis of exudative pharyngitis.'),
#  ('SSEF', 2023, 'RO043', 'Vessel Trajectory Prediction in Maritime Transportation based on deep learning', 'Precise Geolocation data of modern cargo ships allows us to precisely plot a ship’s trajectory. In conjunction with modern machine learning technique ... (1274 characters truncated) ... better as compared to TrAISformer. Across multiple datasets, we are consistently able to better predict maritime trajectory than\xa0previous\xa0work.'),
#  ('SSEF', 2023, 'RO050', 'Legal Beagle: Law Classification and Identification App via Novel Deep Learning Graphical Neural Networks and Attention Networks', 'Law is very important to the public. People often do not have the time and/or the knowledge to conduct legal research by themselves. Consultation wit ... (1456 characters truncated) ... and finally the relevant acts that are related to the user’s case. This will all be packaged into a custom app to allow it to be accessible to users.'),
#  ('SSEF', 2023, 'SS001', 'Automated Scanning of Software Packages in Compiled Binaries', 'Vulnerabilities in open-source software pose dangers to users because malicious actors can exploit these vulnerabilities to compromise software secur ... (1453 characters truncated) ... nctions. This can be applied to other use cases such as discovering new vulnerabilities, improving the overall cybersecurity of open-source projects.'),
#  ('SSEF', 2023, 'SS020', 'LEDA: A Lightweight Game Engine using C++ Component-Based Techniques', 'Game engines are tools commonly used by software developers to create dynamic applications, containing ready-made functions that clients can use. How ... (1236 characters truncated) ... ible option for newer developers who are beginning to create their own applications without being intimidated by larger, commercial-use game engines.'),
#  ('SSEF', 2023, 'SS024', 'Interpreting and Evading Visualization-Based Deep Learning Malware Classifiers', 'Machine learning has seen increasing usage in the field of cybersecurity, particularly for the classification of malware. Visualization-based techniq ... (1146 characters truncated) ... tion-based deep learning classifiers due to low interpretability and ease of evasion, contrary to recent research output which claims its robustness.'),
#  ('SSEF', 2023, 'TM006', 'Effect of Animal Extract on Wound Healing in 3T3 Fibroblasts\u200b', ''),
#  ('STYau', 2022, 'Comp-129', 'Law Identification And Classification Text Bot Using Modified Elbow Method And Bidirectional Encoder Representation From Transformers', 'Law is very important to the public. People often do not have the time and/or the knowledge to conduct legal research by themselves. Consultation wit ... (1456 characters truncated) ... and finally the relevant acts that are related to the user’s case. This will all be packaged into a custom app to allow it to be accessible to users.')]

# %%
# %%sql
# SELECT * FROM Submits
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 205 rows affected.
# [('h1810111@nushigh.edu.sg', '20.022.NUSE.PH', 'GYSTB', 2021, 'IBPE07'),
#  ('h1810111@nushigh.edu.sg', '20.022.NUSE.PH', 'IRC-SET', 2021, 'P23'),
#  ('h1810111@nushigh.edu.sg', '20.022.NUSE.PH', 'isyfDigital', 2021, '20.022.NUSE.PH'),
#  ('h1810111@nushigh.edu.sg', '20.022.NUSE.PH', 'SSEF', 2021, 'BE018'),
#  ('h1810124@nushigh.edu.sg', '20.022.NUSE.PH', 'GYSTB', 2021, 'IBPE07'),
#  ('h1810124@nushigh.edu.sg', '20.022.NUSE.PH', 'IRC-SET', 2021, 'P23'),
#  ('h1810124@nushigh.edu.sg', '20.022.NUSE.PH', 'isyfDigital', 2021, '20.022.NUSE.PH'),
#  ('h1810124@nushigh.edu.sg', '20.022.NUSE.PH', 'SSEF', 2021, 'BE018'),
#  ('h1810167@nushigh.edu.sg', '20.022.NUSE.PH', 'GYSTB', 2021, 'IBPE07'),
#  ('h1810167@nushigh.edu.sg', '20.022.NUSE.PH', 'IRC-SET', 2021, 'P23'),
#  ('h1810167@nushigh.edu.sg', '20.022.NUSE.PH', 'isyfDigital', 2021, '20.022.NUSE.PH'),
#  ('h1810167@nushigh.edu.sg', '20.022.NUSE.PH', 'SSEF', 2021, 'BE018'),
#  ('h1810068@nushigh.edu.sg', '21.029.SUTD.CS', 'SSEF', 2022, 'RO014'),
#  ('h1810124@nushigh.edu.sg', '21.029.SUTD.CS', 'SSEF', 2022, 'RO014'),
#  ('h1810104@nushigh.edu.sg', '21.048.NSPC.PH', 'SSEF', 2023, 'ES009'),
#  ('h2030011@nushigh.edu.sg', '21.050.NSPC.PH', 'SSEF', 2023, 'ET018'),
#  ('h1810015@nushigh.edu.sg', '21.122.NUSC.CM', 'SSEF', 2023, 'EE020'),
#  ('h1810075@nushigh.edu.sg', '21.122.NUSC.CM', 'SSEF', 2023, 'EE020'),
#  ('h1810151@nushigh.edu.sg', '21.122.NUSC.CM', 'SSEF', 2023, 'EE020'),
#  ('h1810073@nushigh.edu.sg', '21.123.NUH_.BI', 'SSEF', 2023, 'BM024'),
#  ('h1810108@nushigh.edu.sg', '22.005.NUSH.BI', 'SSEF', 2023, 'EA016'),
#  ('h2030005@nushigh.edu.sg', '22.005.NUSH.BI', 'SSEF', 2023, 'EA016'),
#  ('h1810084@nushigh.edu.sg', '22.009.NUSH.PH', 'SSEF', 2022, 'PH008'),
#  ('h1810038@nushigh.edu.sg', '22.011.NUSH.PH', 'SSEF', 2023, 'PH022'),
#  ('h1810159@nushigh.edu.sg', '22.011.NUSH.PH', 'SSEF', 2023, 'PH022'),
#  ('h1810057@nushigh.edu.sg', '22.031.NERI.CM', 'SSEF', 2023, 'CH005'),
#  ('h1810094@nushigh.edu.sg', '22.031.NERI.CM', 'SSEF', 2023, 'CH005'),
#  ('h1810136@nushigh.edu.sg', '22.031.NERI.CM', 'SSEF', 2023, 'CH005'),
#  ('h1910049@nushigh.edu.sg', '22.032.IMRE.CM', 'SSEF', 2023, 'EY010'),
#  ('h1710026@nushigh.edu.sg', '22.034.NUSP.PH', 'SSEF', 2023, 'MS033'),
#  ('h1810033@nushigh.edu.sg', '22.034.NUSP.PH', 'SSEF', 2023, 'MS033'),
#  ('h1810093@nushigh.edu.sg', '22.034.NUSP.PH', 'SSEF', 2023, 'MS033'),
#  ('h2010042@nushigh.edu.sg', '22.039.NUSB.BI', 'SSEF', 2023, 'PS022'),
#  ('h2010089@nushigh.edu.sg', '22.039.NUSB.BI', 'SSEF', 2023, 'PS022'),
#  ('h2010129@nushigh.edu.sg', '22.039.NUSB.BI', 'SSEF', 2023, 'PS022'),
#  ('h1910059@nushigh.edu.sg', '22.041.SMU_.MA', 'SSEF', 2023, 'RO050'),
#  ('h1910059@nushigh.edu.sg', '22.041.SMU_.MA', 'STYau', 2022, 'Comp-129'),
#  ('h1910099@nushigh.edu.sg', '22.041.SMU_.MA', 'SSEF', 2023, 'RO050'),
#  ('h1910099@nushigh.edu.sg', '22.041.SMU_.MA', 'STYau', 2022, 'Comp-129'),
#  ('h1910153@nushigh.edu.sg', '22.041.SMU_.MA', 'SSEF', 2023, 'RO050'),
#  ('h1910153@nushigh.edu.sg', '22.041.SMU_.MA', 'STYau', 2022, 'Comp-129'),
#  ('h1910016@nushigh.edu.sg', '22.042.SCS_.MA', 'SSEF', 2023, 'MA018'),
#  ('h1810027@nushigh.edu.sg', '22.043.YLL_.BI', 'SSEF', 2023, 'BE026'),
#  ('h1810067@nushigh.edu.sg', '22.043.YLL_.BI', 'SSEF', 2023, 'BE026'),
#  ('h1810169@nushigh.edu.sg', '22.043.YLL_.BI', 'SSEF', 2023, 'BE026'),
#  ('h1810109@nushigh.edu.sg', '22.044.YLL_.BI', 'SSEF', 2023, 'BE024'),
#  ('h2030001@nushigh.edu.sg', '22.044.YLL_.BI', 'SSEF', 2023, 'BE024'),
#  ('h1810110@nushigh.edu.sg', '22.045.NIE_.PH', 'SSEF', 2023, 'PH029'),
#  ('h1810132@nushigh.edu.sg', '22.045.NIE_.PH', 'SSEF', 2023, 'PH029'),
#  ('h1810142@nushigh.edu.sg', '22.045.NIE_.PH', 'SSEF', 2023, 'PH029'),
#  ('h1810145@nushigh.edu.sg', '22.047.NUSC.CM', 'SSEF', 2023, 'MS025'),
#  ('h2010025@nushigh.edu.sg', '22.050.SUTD.CM', 'SSEF', 2023, 'EE029'),
#  ('h2010077@nushigh.edu.sg', '22.050.SUTD.CM', 'SSEF', 2023, 'EE029'),
#  ('h2010164@nushigh.edu.sg', '22.050.SUTD.CM', 'SSEF', 2023, 'EE029'),
#  ('h1910091@nushigh.edu.sg', '22.051.NUSC.CM', 'SSEF', 2023, 'CH032'),
#  ('h1910113@nushigh.edu.sg', '22.051.NUSC.CM', 'SSEF', 2023, 'CH032'),
#  ('h1910126@nushigh.edu.sg', '22.051.NUSC.CM', 'SSEF', 2023, 'CH032'),
#  ('h1910040@nushigh.edu.sg', '22.052.NUS_.PH', 'SSEF', 2023, 'ET009'),
#  ('h1910136@nushigh.edu.sg', '22.052.NUS_.PH', 'SSEF', 2023, 'ET009'),
#  ('h2130010@nushigh.edu.sg', '22.052.NUS_.PH', 'SSEF', 2023, 'ET009'),
#  ('h1810022@nushigh.edu.sg', '22.053.NUSE.CM', 'SSEF', 2023, 'EE018'),
#  ('h1810092@nushigh.edu.sg', '22.053.NUSE.CM', 'SSEF', 2023, 'EE018'),
#  ('h1810043@nushigh.edu.sg', '22.054.IMRE.PH', 'SSEF', 2023, 'MS041'),
#  ('h1810088@nushigh.edu.sg', '22.054.IMRE.PH', 'SSEF', 2023, 'MS041'),
#  ('h1810144@nushigh.edu.sg', '22.054.IMRE.PH', 'SSEF', 2023, 'MS041'),
#  ('h1810003@nushigh.edu.sg', '22.055.IMRE.PH', 'SSEF', 2023, 'MS001'),
#  ('h1810017@nushigh.edu.sg', '22.055.IMRE.PH', 'SSEF', 2023, 'MS001'),
#  ('h1810141@nushigh.edu.sg', '22.055.IMRE.PH', 'SSEF', 2023, 'MS001'),
#  ('h1810070@nushigh.edu.sg', '22.057.DSO_.PH', 'SSEF', 2023, 'PH015'),
#  ('h1910090@nushigh.edu.sg', '22.058.DSO_.CS', 'SSEF', 2023, 'RO030'),
#  ('h1910158@nushigh.edu.sg', '22.058.DSO_.CS', 'SSEF', 2023, 'RO030'),
#  ('h1810055@nushigh.edu.sg', '22.059.DSO_.CS', 'SSEF', 2023, 'SS001'),
#  ('h1810139@nushigh.edu.sg', '22.059.DSO_.CS', 'SSEF', 2023, 'SS001'),
#  ('h1810014@nushigh.edu.sg', '22.064.SIGN.BI', 'SSEF', 2023, 'MI009'),
#  ('h1810040@nushigh.edu.sg', '22.064.SIGN.BI', 'SSEF', 2023, 'MI009'),
#  ('h1810016@nushigh.edu.sg', '22.065.SIGN.BI', 'SSEF', 2023, 'BI007'),
#  ('h1810107@nushigh.edu.sg', '22.065.SIGN.BI', 'SSEF', 2023, 'BI007'),
#  ('h1810053@nushigh.edu.sg', '22.066.NIE_.PH', 'SSEF', 2023, 'EY007'),
#  ('h1810137@nushigh.edu.sg', '22.066.NIE_.PH', 'SSEF', 2023, 'EY007'),
#  ('h1810013@nushigh.edu.sg', '22.069.SERI.PH', 'SSEF', 2023, 'EY003'),
#  ('h1810034@nushigh.edu.sg', '22.069.SERI.PH', 'SSEF', 2023, 'EY003'),
#  ('h1810090@nushigh.edu.sg', '22.070.NTU_.CM', 'SSEF', 2023, 'MS020'),
#  ('h1810050@nushigh.edu.sg', '22.074.IMRE.CM', 'SSEF', 2023, 'CH029'),
#  ('h1810037@nushigh.edu.sg', '22.076.SUTD.HU', 'SSEF', 2023, 'BH021'),
#  ('h1810115@nushigh.edu.sg', '22.076.SUTD.HU', 'SSEF', 2023, 'BH021'),
#  ('h1810166@nushigh.edu.sg', '22.077.SUTD.PH', 'SSEF', 2023, 'BE018'),
#  ('h2030008@nushigh.edu.sg', '22.077.SUTD.PH', 'SSEF', 2023, 'BE018'),
#  ('h1810044@nushigh.edu.sg', '22.078.IMRE.CM', 'SSEF', 2023, 'CH028'),
#  ('h1810130@nushigh.edu.sg', '22.078.IMRE.CM', 'SSEF', 2023, 'CH028'),
#  ('h1810002@nushigh.edu.sg', '22.084.NUSB.BI', 'SSEF', 2023, 'AS007'),
#  ('h1810163@nushigh.edu.sg', '22.084.NUSB.BI', 'SSEF', 2023, 'AS007'),
#  ('h2030013@nushigh.edu.sg', '22.084.NUSB.BI', 'SSEF', 2023, 'AS007'),
#  ('h1810012@nushigh.edu.sg', '22.085.SICS.BI', 'SSEF', 2023, 'BM019'),
#  ('h1810155@nushigh.edu.sg', '22.085.SICS.BI', 'SSEF', 2023, 'BM019'),
#  ('h1810005@nushigh.edu.sg', '22.086.YLL_.BI', 'SSEF', 2023, 'MI001'),
#  ('h1810030@nushigh.edu.sg', '22.086.YLL_.BI', 'SSEF', 2023, 'MI001'),
#  ('h1810082@nushigh.edu.sg', '22.086.YLL_.BI', 'SSEF', 2023, 'MI001'),
#  ('h1810004@nushigh.edu.sg', '22.087.CNGP.CS', 'SSEF', 2023, 'RO043'),
#  ('h1810129@nushigh.edu.sg', '22.087.CNGP.CS', 'SSEF', 2023, 'RO043'),
#  ('h2030002@nushigh.edu.sg', '22.087.CNGP.CS', 'SSEF', 2023, 'RO043'),
#  ('h1810007@nushigh.edu.sg', '22.088.YLL_.RE', 'SSEF', 2023, 'BM018'),
#  ('h1810064@nushigh.edu.sg', '22.088.YLL_.RE', 'SSEF', 2023, 'BM018'),
#  ('h1810052@nushigh.edu.sg', '22.090.SRIS.BI', 'SSEF', 2023, 'TM006'),
#  ('h1810069@nushigh.edu.sg', '22.090.SRIS.BI', 'SSEF', 2023, 'TM006'),
#  ('h1810128@nushigh.edu.sg', '22.091.NUSB.BI', 'SSEF', 2023, 'EA014'),
#  ('h1810098@nushigh.edu.sg', '22.092.NUSH.MA', 'SSEF', 2023, 'MA017'),
#  ('h1810160@nushigh.edu.sg', '22.092.NUSH.MA', 'SSEF', 2023, 'MA017'),
#  ('h2030003@nushigh.edu.sg', '22.092.NUSH.MA', 'SSEF', 2023, 'MA017'),
#  ('h1810071@nushigh.edu.sg', '22.096.NUH_.BI', 'SSEF', 2023, 'BM001'),
#  ('h1810156@nushigh.edu.sg', '22.096.NUH_.BI', 'SSEF', 2023, 'BM001'),
#  ('h1810158@nushigh.edu.sg', '22.096.NUH_.BI', 'SSEF', 2023, 'BM001'),
#  ('h1810011@nushigh.edu.sg', '22.097.YLL_.BI', 'SSEF', 2023, 'CB016'),
#  ('h1810112@nushigh.edu.sg', '22.097.YLL_.BI', 'SSEF', 2023, 'CB016'),
#  ('h1810127@nushigh.edu.sg', '22.097.YLL_.BI', 'SSEF', 2023, 'CB016'),
#  ('h1810149@nushigh.edu.sg', '22.099.NUSC.CM', 'SSEF', 2023, 'MS037'),
#  ('h1810143@nushigh.edu.sg', '22.100.NTU_.RE', 'SSEF', 2023, 'RO040'),
#  ('h1810099@nushigh.edu.sg', '22.101.IMRE.PH', 'SSEF', 2023, 'PH017'),
#  ('h1810010@nushigh.edu.sg', '22.103.NUSB.BI', 'SSEF', 2023, 'EA007'),
#  ('h1810083@nushigh.edu.sg', '22.103.NUSB.BI', 'SSEF', 2023, 'EA007'),
#  ('h1810119@nushigh.edu.sg', '22.103.NUSB.BI', 'SSEF', 2023, 'EA007'),
#  ('h1810026@nushigh.edu.sg', '22.104.IHPC.RE', 'SSEF', 2023, 'BH017'),
#  ('h1810089@nushigh.edu.sg', '22.104.IHPC.RE', 'SSEF', 2023, 'BH017'),
#  ('h1810121@nushigh.edu.sg', '22.104.IHPC.RE', 'SSEF', 2023, 'BH017'),
#  ('h1910013@nushigh.edu.sg', '22.105.DSO_.PH', 'SSEF', 2023, 'ES005'),
#  ('h1810061@nushigh.edu.sg', '22.106.YLL_.BI', 'SSEF', 2023, 'CB021'),
#  ('h1810102@nushigh.edu.sg', '22.106.YLL_.BI', 'SSEF', 2023, 'CB021'),
#  ('h1810123@nushigh.edu.sg', '22.106.YLL_.BI', 'SSEF', 2023, 'CB021'),
#  ('h1810086@nushigh.edu.sg', '22.107.NUSG.CS', 'SSEF', 2023, 'SS024'),
#  ('h1810024@nushigh.edu.sg', '22.109.NUSC.CM', 'SSEF', 2023, 'CH034'),
#  ('h1810045@nushigh.edu.sg', '22.109.NUSC.CM', 'SSEF', 2023, 'CH034'),
#  ('h1810078@nushigh.edu.sg', '22.109.NUSC.CM', 'SSEF', 2023, 'CH034'),
#  ('h1910140@nushigh.edu.sg', '22.113.NUSH.MA', 'SSEF', 2023, 'MA023'),
#  ('h2130007@nushigh.edu.sg', '22.113.NUSH.MA', 'SSEF', 2023, 'MA023'),
#  ('h2010018@nushigh.edu.sg', '22.114.NUSH.MA', 'SSEF', 2023, 'MA013'),
#  ('h2010103@nushigh.edu.sg', '22.114.NUSH.MA', 'SSEF', 2023, 'MA013'),
#  ('h2010104@nushigh.edu.sg', '22.114.NUSH.MA', 'SSEF', 2023, 'MA013'),
#  ('h1910027@nushigh.edu.sg', '22.115.NUSH.MA', 'SSEF', 2023, 'MA021'),
#  ('h1910155@nushigh.edu.sg', '22.115.NUSH.MA', 'SSEF', 2023, 'MA021'),
#  ('h1810076@nushigh.edu.sg', '22.123.BII_.CM', 'SSEF', 2023, 'CO001'),
#  ('h1810085@nushigh.edu.sg', '22.123.BII_.CM', 'SSEF', 2023, 'CO001'),
#  ('h1810157@nushigh.edu.sg', '22.123.BII_.CM', 'SSEF', 2023, 'CO001'),
#  ('h1810032@nushigh.edu.sg', '22.124.NTU_.PH', 'SSEF', 2023, 'PH025'),
#  ('h1810054@nushigh.edu.sg', '22.124.NTU_.PH', 'SSEF', 2023, 'PH025'),
#  ('h1810161@nushigh.edu.sg', '22.125.NUSE.CM', 'SSEF', 2023, 'EE030'),
#  ('h2030006@nushigh.edu.sg', '22.125.NUSE.CM', 'SSEF', 2023, 'EE030'),
#  ('h1810009@nushigh.edu.sg', '22.126.NUSH.MA', 'SSEF', 2023, 'MA030'),
#  ('h1810039@nushigh.edu.sg', '22.126.NUSH.MA', 'SSEF', 2023, 'MA030'),
#  ('h1810025@nushigh.edu.sg', '22.129.NUSA.CM', 'SSEF', 2023, 'MS004'),
#  ('h1810077@nushigh.edu.sg', '22.129.NUSA.CM', 'SSEF', 2023, 'MS004'),
#  ('h1810021@nushigh.edu.sg', '22.133.NUSB.BI', 'SSEF', 2023, 'EA009'),
#  ('h1810063@nushigh.edu.sg', '22.133.NUSB.BI', 'SSEF', 2023, 'EA009'),
#  ('h1810131@nushigh.edu.sg', '22.133.NUSB.BI', 'SSEF', 2023, 'EA009'),
#  ('h1810133@nushigh.edu.sg', '22.134.LKCS.BI', 'SSEF', 2023, 'BM021'),
#  ('h1810134@nushigh.edu.sg', '22.134.LKCS.BI', 'SSEF', 2023, 'BM021'),
#  ('h1810135@nushigh.edu.sg', '22.134.LKCS.BI', 'SSEF', 2023, 'BM021'),
#  ('h1810120@nushigh.edu.sg', '22.135.IHPC.BI', 'SSEF', 2023, 'BH009'),
#  ('h1810126@nushigh.edu.sg', '22.137.DIGI.CS', 'SSEF', 2023, 'SS020'),
#  ('h1810146@nushigh.edu.sg', '22.137.DIGI.CS', 'SSEF', 2023, 'SS020'),
#  ('h1910004@nushigh.edu.sg', '22.140.NUSC.CM', 'SSEF', 2023, 'MS031'),
#  ('h1910086@nushigh.edu.sg', '22.140.NUSC.CM', 'SSEF', 2023, 'MS031'),
#  ('h1910102@nushigh.edu.sg', '22.140.NUSC.CM', 'SSEF', 2023, 'MS031'),
#  ('h1810068@nushigh.edu.sg', '22.141.NUSH.CS', 'SSEF', 2023, 'RO032'),
#  ('h1810153@nushigh.edu.sg', '22.141.NUSH.CS', 'SSEF', 2023, 'RO032'),
#  ('h2030012@nushigh.edu.sg', '22.141.NUSH.CS', 'SSEF', 2023, 'RO032'),
#  ('h1810081@nushigh.edu.sg', '22.142.NUSH.CS', 'SSEF', 2023, 'RO028'),
#  ('h1910001@nushigh.edu.sg', '22.143.NUSH.CM', 'SSEF', 2023, 'EE002'),
#  ('h1910117@nushigh.edu.sg', '22.143.NUSH.CM', 'SSEF', 2023, 'EE002'),
#  ('h1810162@nushigh.edu.sg', '22.144.NUSB.RE', 'SSEF', 2023, 'AS004'),
#  ('h1810087@nushigh.edu.sg', '22.147.NUSC.CM', 'SSEF', 2023, 'CH035'),
#  ('h1810147@nushigh.edu.sg', '22.147.NUSC.CM', 'SSEF', 2023, 'CH035'),
#  ('h1910048@nushigh.edu.sg', '22.149.NUSC.CM', 'SSEF', 2023, 'CB017'),
#  ('h1910098@nushigh.edu.sg', '22.149.NUSC.CM', 'SSEF', 2023, 'CB017'),
#  ('h1910108@nushigh.edu.sg', '22.149.NUSC.CM', 'SSEF', 2023, 'CB017'),
#  ('h1810167@nushigh.edu.sg', '22.155.IMCB.BI', 'SSEF', 2023, 'CB022'),
#  ('h1810122@nushigh.edu.sg', '22.157.NUSH.BI', 'SSEF', 2023, 'AS008'),
#  ('h1810152@nushigh.edu.sg', '23.001.NUSH.MA', 'SSEF', 2023, 'MA019'),
#  ('h1810154@nushigh.edu.sg', '23.001.NUSH.MA', 'SSEF', 2023, 'MA019'),
#  ('h2010009@nushigh.edu.sg', '23.002.NUSH.BI', 'SSEF', 2023, 'PS049'),
#  ('h2010118@nushigh.edu.sg', '23.002.NUSH.BI', 'SSEF', 2023, 'PS049'),
#  ('h2010120@nushigh.edu.sg', '23.002.NUSH.BI', 'SSEF', 2023, 'PS049'),
#  ('h2010055@nushigh.edu.sg', '23.003.NUSH.BI', 'SSEF', 2023, 'EE039'),
#  ('h2010169@nushigh.edu.sg', '23.003.NUSH.BI', 'SSEF', 2023, 'EE039'),
#  ('h1810079@nushigh.edu.sg', '23.006.NSPC.PH', 'SSEF', 2023, 'ES008'),
#  ('h1810116@nushigh.edu.sg', '23.006.NSPC.PH', 'SSEF', 2023, 'ES008'),
#  ('h1810084@nushigh.edu.sg', '23.007.NUSH.CS', 'SSEF', 2023, 'BE022'),
#  ('h1810125@nushigh.edu.sg', '23.007.NUSH.CS', 'SSEF', 2023, 'BE022'),
#  ('ashwin_lokesh@students.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('h1810086@nushigh.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('h1810124@nushigh.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('ishneet_singh@temasekjc.moe.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('lam.yikting@dhs.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('yau_le_qi@temasekjc.moe.edu.sg', '23.010.SIT_.CS', 'Globecom', 2023, '23.010.SIT_.CS'),
#  ('h1810065@nushigh.edu.sg', '23.011.SGH_.CS', 'SSEF', 2023, 'RO041'),
#  ('h1910133@nushigh.edu.sg', '23.012.NUSB.BI', 'SSEF', 2023, 'PS009'),
#  ('h2130003@nushigh.edu.sg', '23.012.NUSB.BI', 'SSEF', 2023, 'PS009'),
#  ('h2010154@nushigh.edu.sg', '23.016.NUSH.MA', 'SSEF', 2023, 'MA001'),
#  ('h1910157@nushigh.edu.sg', '23.017.NUSH.PH', 'SSEF', 2023, 'PH023'),
#  ('h1810111@nushigh.edu.sg', '23.018.NUSH.CS', 'SSEF', 2023, 'BE023'),
#  ('h1810124@nushigh.edu.sg', '23.018.NUSH.CS', 'SSEF', 2023, 'BE023'),
#  ('h1810074@nushigh.edu.sg', '23.029.NUSH.RE', 'SSEF', 2023, 'BH025'),
#  ('h1810097@nushigh.edu.sg', '23.029.NUSH.RE', 'SSEF', 2023, 'BH025'),
#  ('h1810168@nushigh.edu.sg', '23.029.NUSH.RE', 'SSEF', 2023, 'BH025'),
#  ('h1810035@nushigh.edu.sg', '23.031.IMCB.RE', 'SSEF', 2023, 'AS009'),
#  ('h1810114@nushigh.edu.sg', '23.031.IMCB.RE', 'SSEF', 2023, 'AS009'),
#  ('h1810105@nushigh.edu.sg', '23.036.IBB_.BI', 'SSEF', 2023, 'CB018')]

# %%
# %%sql
# SELECT * FROM Accomplishment
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 40 rows affected.
# [(1, 1, '2nd Place', '', 'ISYFdigital', 2021, '20.022.NUSE.PH'),
#  (2, 1, 'Gold Award', 'S$800 in Popular Vouchers', 'SSEF', 2021, 'BE018'),
#  (3, 1, 'Third Prize', '', 'GYSTB', 2021, 'IBPE07'),
#  (4, 1, "Best Presenters' Award", '', 'IRC-SET', 2021, 'P23'),
#  (5, 0, '', '', 'IRC-SET', 2021, 'P23'),
#  (6, 1, 'Bronze Award', 'S$100 in Popular Vouchers', 'SSEF', 2022, 'PH008'),
#  (7, 1, 'Harry Shum High School Computer Science Gold Award', 'US$1000', 'STYau', 2022, 'Comp-129'),
#  (8, 1, 'Gold Award', 'S$400 in Popular Vouchers', 'SSEF', 2023, 'AS004'),
#  (9, 1, 'Gold Award', 'S$600 in Popular Vouchers', 'SSEF', 2023, 'BE023'),
#  (10, 1, 'Gold Award', 'S$400 in Popular Vouchers', 'SSEF', 2023, 'EY010'),
#  (11, 1, 'Gold Award', 'S$600 in Popular Vouchers', 'SSEF', 2023, 'MA021'),
#  (12, 1, 'Gold Award', 'S$600 in Popular Vouchers', 'SSEF', 2023, 'PH015'),
#  (13, 1, 'Gold Award', 'S$800 in Popular Vouchers', 'SSEF', 2023, 'ES005'),
#  (14, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'BE018'),
#  (15, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'BE023'),
#  (16, 1, 'Silver Award', 'S$250 in Popular Vouchers', 'SSEF', 2023, 'SS024'),
#  (17, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'RO030'),
#  (18, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'MI009'),
#  (19, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'EE002'),
#  (20, 1, 'Silver Award', 'S$375 in Popular Vouchers', 'SSEF', 2023, 'PH023'),
#  (21, 1, 'Silver Award', 'S$500 in Popular Vouchers', 'SSEF', 2023, 'BH017'),
#  (22, 1, 'Bronze Award', 'S$300 in Popular Vouchers', 'SSEF', 2023, 'MI001'),
#  (23, 1, 'Bronze Award', 'S$225 in Popular Vouchers', 'SSEF', 2023, 'MA019'),
#  (24, 1, 'Bronze Award', 'S$300 in Popular Vouchers', 'SSEF', 2023, 'EE020'),
#  (25, 1, 'Bronze Award', 'S$150 in Popular Vouchers', 'SSEF', 2023, 'RO028'),
#  (26, 1, 'Bronze Award', 'S$300 in Popular Vouchers', 'SSEF', 2023, 'PS022'),
#  (27, 1, 'Bronze Award', 'S$300 in Popular Vouchers', 'SSEF', 2023, 'BM021'),
#  (28, 1, 'Merit Award', 'S$100 in Popular Vouchers', 'SSEF', 2023, 'CB018'),
#  (29, 1, 'Merit Award', 'S$100 in Popular Vouchers', 'SSEF', 2023, 'CB022'),
#  (30, 1, 'Merit Award', 'S$100 in Popular Vouchers', 'SSEF', 2023, 'MA018'),
#  (31, 1, 'Merit Award', 'S$200 in Popular Vouchers', 'SSEF', 2023, 'EA007'),
#  (32, 1, 'SUTD R&I Award (Healthcare)', '', 'SSEF', 2023, 'BE023'),
#  (33, 1, 'SAAS Poster Award', '', 'SSEF', 2023, 'BE022'),
#  (34, 1, 'SAAS Poster Award', '', 'SSEF', 2023, 'EA007'),
#  (35, 1, 'ECS Special Award', '', 'SSEF', 2023, 'EY007'),
#  (36, 1, 'SAAS Poster Award', '', 'SSEF', 2023, 'EY007'),
#  (37, 0, '', '', 'Globecom', 2023, '23.010.SIT_.CS'),
#  (38, 0, '', '', None, None, None),
#  (39, 0, '', '', None, None, None),
#  (40, 0, '', '', None, None, None)]

# %%
# %%sql
# SELECT * FROM Journal
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 4 rows affected.
# [(2663409, 'The Physics Educator'),
#  (13616404, 'European Journal of Physics'),
#  (15383881, 'The Astronomical Journal'),
#  (18614728, 'Chemistry: An Asian Journal')]

# %%
# %%sql
# SELECT * FROM PublishedBy
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 8 rows affected.
# [(15383881, 'AAS'),
#  (18614728, 'ACES'),
#  (13616404, 'EPS'),
#  (13616404, 'IOP'),
#  (15383881, 'IOP'),
#  (2663409, 'IPS'),
#  (2663409, 'WS'),
#  (18614728, 'WVCH')]

# %%
# %%sql
# SELECT * FROM Publication
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 5 rows affected.
# [(4, "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms", '10.1007/978-981-16-9869-9_21', 0, None, None),
#  (36, 'Detecting Malware Samples using a Novel Feature Vector and Deep Learning Methods', '', 0, None, None),
#  (37, 'An Investigation on the Aerodynamics of Flight of a Hand Helicopter', '10.1142/S2661339523500038', 1, 'https://www.worldscientific.com/doi/abs/10.1142/S2661339523500038', 2663409),
#  (38, 'An Automated Screening System for Trinary Star System Candidates', '', 1, '', 15383881),
#  (39, 'Optically and Wirelessly Re-chargeable Buffer Batteries', '', 1, '', 18614728)]

# %% [markdown]
# ### Section F: Queries Script

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>SQL Query:</b> <br>
#
# * Pose 3 interesting questions (asked by end user/administrator of your domain) and write SELECT queries to answer them. State the question that is being asked for each query, and also a short explanation of why the question is relevant to the domain. If relevant, you may wish to implement the query as a view or stored procedure.
#
# * Write the full SELECT statement that answers the query.
#
# * Each query must be sufficiently complex (join of a few tables, use of aggregate functions, nested queries etc). Ideally, these queries should be implemented in your final web interface.
#
# * Finally, show a copy of the result set produced by each query.
#
# * Please ensure your code can be seen clearly from oneNote.
# </div>

# %% [markdown]
# #### Query 1

# %% [markdown]
# **Who are the students who didn't submit one of their 2023 Projects to SSEF 2023, and if so, how many?**
#
# I.e. students who submitted projects in 2023 (at Research Congress) but didn't submit it to SSEF (because they didn't want to OR they had other projects).
#
# This is helpful for us to identify those students that will need to present their work at the Research Congress, especially as it is easy to miss in the current DBMS.

# %%
# %%sql
# SELECT name, COUNT(projs.pcode) FROM
# (SELECT email, pcode
# FROM NUSHStudent n LEFT JOIN Works_On w
# ON n.email = w.studentEmail
# WHERE NOT pcode = ANY(
#     SELECT pcode FROM submits
#     WHERE eventId = "SSEF" and year = 2023 and studentEmail = w.studentEmail)
# ORDER BY n.email) projs, Student, Project
# WHERE Student.email = projs.email AND Project.pcode = projs.pcode AND project.year = 2023
# GROUP BY name ORDER BY name
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 86 rows affected.
# [('Aditya Kaul', 1),
#  ('Benedict Lee Rui Yang', 2),
#  ('Chew Ker Xyn', 1),
#  ('Chng Yaw Tia', 1),
#  ('Choo Zheng Yu', 1),
#  ('Choo Zhi Yuan Winston', 1),
#  ('Chua Ke Yue', 1),
#  ('Chua Wenn Yu', 1),
#  ('Chua Zhuo Hong Dominic', 1),
#  ('Chung Jia Min', 1),
#  ('Dey Krittika', 1),
#  ('Ernest Emmanuel Cheong Haoen', 1),
#  ('Ho Chun Lei', 1),
#  ('Ho Pin Rui', 1),
#  ('Ho Shing Tat Nicholas', 1),
#  ('Hoang Minh Nam', 1),
#  ('Hrishikesh Sarkar', 1),
#  ('Huang Zehan', 1),
#  ('Hugo Maximus Lim', 1),
#  ('Ian Wang (Yuan Hongyu)', 1),
#  ('Janardhanan Tanish', 1),
#  ('Jeanne Liu Juan', 1),
#  ('Johnson Angelin', 1),
#  ('Jonathan Siju Akkara', 1),
#  ('Jordan Kai-Wei Yeo', 1),
#  ('Jovern Teo', 1),
#  ('Julian Tang Jing Le', 1),
#  ('Kabir Jain', 4),
#  ('Karimi Zayan', 1),
#  ('Keenan Tan Han-Ming', 1),
#  ('Khoo Jun Xin', 2),
#  ('Kon Wei Ren, Mattias', 1),
#  ('Kyusik Kim', 1),
#  ('Lam Eu Ler', 1),
#  ('Lawrence Loke Juin Yi', 1),
#  ('Lee Hayoung', 1),
#  ('Lee I-Shiang', 1),
#  ('Li Mengke', 1),
#  ('Lim Li Xin Jed', 4),
#  ('Lim Lynus', 1),
#  ('Lim Sue Han Justin', 1),
#  ('Lim Yi Kai Timothy', 1),
#  ('Lin Zhining', 1),
#  ('Liu Chenghui', 1),
#  ('Loh Jie Wei (Luo Jiewei)', 1),
#  ('Loh Zi Ting, Michelle', 1),
#  ('Lokesh Vairakannu', 1),
#  ('Markus Ang Sheng', 1),
#  ('Michael Leow Yikai', 1),
#  ('N Apoorva Sasikumar', 1),
#  ('Ng Le Xi', 1),
#  ('Ng Ting Hui', 1),
#  ('Nicholas Adam Khaw Hoong Keat', 1),
#  ('Nicholas Ng Eng Siong', 1),
#  ('Ong Chen Kai, John', 1),
#  ('Ong Kai Ying Charlize', 1),
#  ('Ong Yicheng Shawn', 1),
#  ('Panshul Sharma', 1),
#  ('Prabakaran Sahana', 1),
#  ('Prannaya Gupta', 4),
#  ('Qiu Ziming', 3),
#  ('Rayson Tan You Shen', 1),
#  ('Selvakumar Vigneshwaran', 1),
#  ('Seng Yu Rui', 1),
#  ('Seow Wei Rong Daniel', 1),
#  ('Sim Xin Hui Yeshe', 1),
#  ('Soh Rong Sheng', 1),
#  ('Song Xinpeng, Charles', 2),
#  ('Subramanian Vishwa', 1),
#  ('Tan Shi Wei', 1),
#  ('Tan Zhi Jian David', 1),
#  ('Teoh En Rou', 1),
#  ('Terence Goh Yan Chen', 1),
#  ('Tian Jiarui', 1),
#  ('Vernon Jude Pui Zhi Xuan', 1),
#  ('Vijoy Akshat', 2),
#  ('Vikram Ramanathan', 1),
#  ('Vu Cong Minh Thai', 1),
#  ('Wang Jiayu', 1),
#  ('Woon Kia Yong Daniel', 1),
#  ('Yao Jingwen', 1),
#  ('Yap Jialer', 1),
#  ('Yap Yuan Xi', 2),
#  ('Ye Chen Rui', 1),
#  ('Yeo Wei Han, Luke', 1),
#  ('Yshwantkumar Anandakumar', 1)]

# %% [markdown]
# #### Query 2

# %% [markdown]
# **Which students (and projects) are nominated for NSTS?**
#
# Projects that got either a Gold, Silver or Bronze medal are nominated for National STEAM Talent Search (NSTS). We assume that the representative has the most research experience. This helps us identify the team and start training them.

# %%
# %%sql
# SELECT name, S.studentEmail email, S.pcode, title
# FROM Works_On, submits S, Student stud, Project proj
# WHERE Works_On.studentEmail = stud.email
# AND Works_On.pcode = S.pcode AND proj.pcode = S.pcode
# AND Works_On.studentEmail = S.studentEmail
# AND eventId = "SSEF" AND S.year = "2023"
# AND code in (
#     SELECT code FROM Accomplishment
#     WHERE eventId = "SSEF" AND year = Year(CURDATE()) AND name IN ("Gold Award", "Silver Award", "Bronze Award")
# ) and S.studentEmail = (
#     SELECT studentEmail FROM
#     (SELECT studentEmail, COUNT(pcode) exp
#     FROM Works_On
#     GROUP BY studentEmail) codes NATURAL JOIN Works_On
#     WHERE pcode = S.pcode
#     ORDER BY exp DESC
#     LIMIT 1
# )
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 19 rows affected.
# [('Wong Chin Wen, Rachel', 'h1810162@nushigh.edu.sg', '22.144.NUSB.RE', 'Ecological Footprint of Smallholder vs Industrial Oil Palm Plantations in Indonesia'),
#  ('Yap Yuan Xi', 'h1810166@nushigh.edu.sg', '22.077.SUTD.PH', 'Shielding-Free Signal Noise Suppression in Portable Low-Field MRI'),
#  ('Prannaya Gupta', 'h1810124@nushigh.edu.sg', '23.018.NUSH.CS', "Analysing Gait Patterns of Parkinson's Disease patients to predict Freezing of Gait (FoG) using Machine Learning Algorithms"),
#  ('Chua Zhuo Hong Dominic', 'h1810026@nushigh.edu.sg', '22.104.IHPC.RE', 'Neurocognitive Functioning and School Performance in Students With Special Educational Needs'),
#  ('Saravanan Manobharathi', 'h1810133@nushigh.edu.sg', '22.134.LKCS.BI', 'Tuning T-lymphocytes to improve wound healing'),
#  ('Aarohi Chaudhary', 'h1910001@nushigh.edu.sg', '22.143.NUSH.CM', 'Application of water hyacinth as a low-cost biosorbent for dyes in textile wastewater'),
#  ('Lee I-Shiang', 'h1810075@nushigh.edu.sg', '21.122.NUSC.CM', 'Performance Evaluation of Recycled Acyl-Modified Chitosan Filtration Membranes on Polluted Water Using Spectroscopic Techniques'),
#  ('Benedict Lee Rui Yang', 'h1910013@nushigh.edu.sg', '22.105.DSO_.PH', 'The bird in the swarm: how to detect and resolve closely-spaced targets in radar'),
#  ('Ivan Joel You Wen Jie', 'h1910049@nushigh.edu.sg', '22.032.IMRE.CM', 'Solid State Materials for Energy Harvesting and Cooling: from Materials Synthesis, Characterization, and Analysis to Applications'),
#  ('Terence Goh Yan Chen', 'h1810152@nushigh.edu.sg', '23.001.NUSH.MA', 'Dungeons and Dragons Inspired Cantrip Knockout Prediction: Error-mimimising Numerical Investigative Study'),
#  ('Drew Michael Terren Ramirez', 'h1910027@nushigh.edu.sg', '22.115.NUSH.MA', 'Chromatic Number of Graph Powers'),
#  ('Alicia Jocelyn Tjokro', 'h1810005@nushigh.edu.sg', '22.086.YLL_.BI', 'Optimising in vitro production of late stage Plasmodium falciparum gametocytes for Anopheles sinensis infection'),
#  ('Cervon Wong Teng Hao', 'h1810014@nushigh.edu.sg', '22.064.SIGN.BI', 'Nonlesional skin microbiome differs between children with atopic dermatitis (AD) and those with history of AD'),
#  ('Keenan Tan Han-Ming', 'h1810070@nushigh.edu.sg', '22.057.DSO_.PH', 'Reflectarray design based on rectangular pheonix cell'),
#  ('Vijoy Akshat', 'h1910157@nushigh.edu.sg', '23.017.NUSH.PH', 'On the Vibroacoustic Modelling of Tensioned Elastic Membranes in a Pressurised Air Cavity'),
#  ('Giriraj Gautham', 'h2010042@nushigh.edu.sg', '22.039.NUSB.BI', 'Understanding the Genetic Basis of Resistance to Combined Heat and Drought stress in Arabidopsis thaliana accessions response to heat and drought stress'),
#  ('Liew Wei Pyn', 'h1810081@nushigh.edu.sg', '22.142.NUSH.CS', 'Deep Equilibrium BERT'),
#  ('Liu Wenkai', 'h1910090@nushigh.edu.sg', '22.058.DSO_.CS', 'Explainable Video Analytics - A wide area multi-camera tracking perspective'),
#  ('Lim Sue Han Justin', 'h1810086@nushigh.edu.sg', '22.107.NUSG.CS', 'Interpreting and Evading Visualization-Based Deep Learning Malware Classifiers')]

# %% [markdown]
# #### Query 3

# %% [markdown]
# **Which teacher in each department is the most available to work as a mentor for a new project?**
#
# Very crucial for the admin staff to allocate projects to mentors.

# %%
# %%sql
# SELECT deptId, email, name
# FROM (SELECT deptId, (SELECT email
# FROM (SELECT email, name, (CASE WHEN NUSHTeacher.deptId = "EL" THEN "HU" else NUSHTeacher.deptId END) deptId, COUNT(Project.title) projs
# FROM NUSHTeacher JOIN Project
# ON NUSHTeacher.email = Project.teacherEmail
# WHERE Project.year = YEAR(CURDATE())
# group by email, name, NUSHTeacher.deptId
# #having count(Project.title) > 0
# ) counts
# where deptId = Department.deptId
# order by projs limit 1) email
# FROM Department
# WHERE deptId <> "EL") teacher NATURAL JOIN NUSHTeacher
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 6 rows affected.
# [('BI', 'nhslowkl@nushigh.edu.sg', 'Dr Low Kai Leng'),
#  ('CM', 'nhsnyr@nushigh.edu.sg', 'Ms Ng Yu Rui'),
#  ('CS', 'nhsld@nushigh.edu.sg', 'Mr Li Da'),
#  ('MA', 'nhscmh@nushigh.edu.sg', 'Mr Chai Ming Huang Royce'),
#  ('PH', 'nhstsk@nushigh.edu.sg', 'Mr Tan Soon Kee @ Hariz Tan'),
#  ('RE', 'nhsaj@nushigh.edu.sg', 'Mr Andre Jusuf')]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Triggers and Events:</b> <br>
# Shortlist relevant triggers or scheduled events that are useful for your database system.
# Describe what the trigger/event is for and why it is useful for your DB.
# </div>

# %% [markdown]
# #### Trigger/Event

# %% [markdown]
# When we insert an entry into the NUSH Student table, we can immediately compute the NUSH Student ID.

# %%
# %%sql
# CREATE TRIGGER IF NOT EXISTS student_id_insert
# BEFORE INSERT ON NUSHStudent
# FOR EACH ROW
# SET NEW.nush_sid = SUBSTR(NEW.email, 1, 8);
#
# CREATE TRIGGER IF NOT EXISTS student_id_update
# BEFORE INSERT ON NUSHStudent
# FOR EACH ROW
# SET NEW.nush_sid = SUBSTR(NEW.email, 1, 8);
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO Student
# VALUES ("h1710001@nushigh.edu.sg", "name");
#
# INSERT INTO NUSHStudent(email, pwd, gradYear)
# VALUES ("h1710001@nushigh.edu.sg", "hello", 2022);
#
# SELECT * FROM NUSHStudent
# WHERE gradYear = 2022;
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# [('h1710001@nushigh.edu.sg', 'hello', None, 2022, 'h1710001')]

# %%
# %%sql
# SELECT name, title FROM Student, Works_On, Project WHERE name = "Lim Li Xin Jed" and Student.email = Works_on.studentEmail and Works_on.pcode = Project.pcode
# Out:
#  * mysql+mysqldb://root:***@localhost/
# 6 rows affected.
# [('Lim Li Xin Jed', 'An Investigation on the Aerodynamics of Flight of a Hand Helicopter'),
#  ('Lim Li Xin Jed', 'Real-World Implementation and Security Analysis of Structured Encryption on Amazon-Web Services'),
#  ('Lim Li Xin Jed', 'Low Dose, High Accuracy: Using Deep Learning to Enhance 3D Tomography'),
#  ('Lim Li Xin Jed', 'Three Dimensional Modelling of the Maximum Fluid Load on a Horizontally Rotating Cylinder'),
#  ('Lim Li Xin Jed', 'Numerical Simulation of Small Floating Particles on a Fluid Surface under the Influence of a Magnetic Field'),
#  ('Lim Li Xin Jed', 'Theoretical and Experimental Analysis into the Accuracy of the Rayleigh Disk')]

# %% [markdown]
# <hr>
# © NUS High School of Math & Science
